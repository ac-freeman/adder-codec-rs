# %%
# for i in range(4):
#     %run log_analyzer.ipynb

# %%
import os
import random

# Get the files randomly
# Specify the directory path
directory_path = '/media/andrew/ExternalM2/VIRAT/videos_original'

# List all files in the directory
file_list = os.listdir(directory_path)

# Randomly select 15 unique file paths
random_file_paths = random.sample(file_list, 16)

# Create the full file paths
full_file_paths = [os.path.join(directory_path, filename) for filename in random_file_paths]

print(full_file_paths)
# Out:
# ['/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010203_06_000620_000760.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040001_02_001102_001530.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_000200_02_000479_000635.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010111_08_000920_000954.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_06_000702_000744.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_05_000658_000700.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010004_06_000547_000715.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010202_03_000313_000355.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_08_001235_001295.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010206_00_000007_000035.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_07_001014_001126.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050201_00_000012_000116.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050300_09_001789_001858.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010204_09_001285_001336.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_00_000063_000085.mp4', '/media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_04_000532_000622.mp4']

# %%
# Suppress cargo build warnings
# %env RUSTFLAGS=-Awarnings
for file_path in full_file_paths:
    for i in range(10):
        print("Running CRF", i)
        ! cargo run --bin evaluate_feature_detection_transcode --release --features "open-cv feature-logging" -- \
                --crf {i} --delta-t-max 76500 --frame-count-max 500 \
                --input-filename {file_path} \
                --scale 0.5 --detect-features
    # --color-input
# Out:
# env: RUSTFLAGS=-Awarnings
# Running CRF 0
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010203_06_000620_000760.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 104133 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010203_06_000620_000760.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105770 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010203_06_000620_000760.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107433 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010203_06_000620_000760.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107734 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010203_06_000620_000760.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107482 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010203_06_000620_000760.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107093 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010203_06_000620_000760.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107319 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010203_06_000620_000760.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107461 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010203_06_000620_000760.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107126 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010203_06_000620_000760.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106635 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040001_02_001102_001530.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 254777 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040001_02_001102_001530.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 260523 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040001_02_001102_001530.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 255092 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040001_02_001102_001530.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 254898 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040001_02_001102_001530.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 255340 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.16s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040001_02_001102_001530.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 256409 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040001_02_001102_001530.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 258304 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040001_02_001102_001530.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 258579 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040001_02_001102_001530.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 258388 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.16s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040001_02_001102_001530.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 257748 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_000200_02_000479_000635.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107270 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.16s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_000200_02_000479_000635.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106245 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_000200_02_000479_000635.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107728 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_000200_02_000479_000635.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 110588 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_000200_02_000479_000635.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 109241 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_000200_02_000479_000635.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 109094 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_000200_02_000479_000635.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107548 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_000200_02_000479_000635.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107097 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_000200_02_000479_000635.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 108091 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.16s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_000200_02_000479_000635.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106682 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010111_08_000920_000954.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 121547 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010111_08_000920_000954.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 120065 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010111_08_000920_000954.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 121051 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010111_08_000920_000954.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 121403 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010111_08_000920_000954.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 121279 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010111_08_000920_000954.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 120869 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010111_08_000920_000954.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 120329 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010111_08_000920_000954.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 119700 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010111_08_000920_000954.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 118387 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010111_08_000920_000954.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 118351 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_06_000702_000744.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106714 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_06_000702_000744.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106354 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_06_000702_000744.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107668 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_06_000702_000744.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107220 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_06_000702_000744.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106893 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_06_000702_000744.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107452 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_06_000702_000744.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106475 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_06_000702_000744.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106377 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_06_000702_000744.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106588 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_06_000702_000744.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106145 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_05_000658_000700.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105502 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_05_000658_000700.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105462 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_05_000658_000700.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106646 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_05_000658_000700.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106916 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_05_000658_000700.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106619 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_05_000658_000700.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106114 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_05_000658_000700.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106705 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_05_000658_000700.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106479 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_05_000658_000700.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106473 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010200_05_000658_000700.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105822 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010004_06_000547_000715.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 116913 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010004_06_000547_000715.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 114937 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010004_06_000547_000715.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 113183 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010004_06_000547_000715.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 114682 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010004_06_000547_000715.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 114734 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010004_06_000547_000715.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 114322 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010004_06_000547_000715.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 114137 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010004_06_000547_000715.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 114031 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010004_06_000547_000715.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 114552 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010004_06_000547_000715.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 113722 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010202_03_000313_000355.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 104876 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010202_03_000313_000355.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105174 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010202_03_000313_000355.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106066 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010202_03_000313_000355.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106295 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010202_03_000313_000355.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106401 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010202_03_000313_000355.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106694 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010202_03_000313_000355.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106843 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010202_03_000313_000355.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106359 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010202_03_000313_000355.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 104731 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010202_03_000313_000355.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105419 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_08_001235_001295.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 236596 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_08_001235_001295.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 239656 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_08_001235_001295.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 237432 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_08_001235_001295.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 239714 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_08_001235_001295.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 241742 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_08_001235_001295.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 243034 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_08_001235_001295.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 245105 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_08_001235_001295.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 245052 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_08_001235_001295.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 244818 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_08_001235_001295.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 243932 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010206_00_000007_000035.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105926 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010206_00_000007_000035.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 104855 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010206_00_000007_000035.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106176 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010206_00_000007_000035.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106385 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010206_00_000007_000035.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105992 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010206_00_000007_000035.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105767 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010206_00_000007_000035.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106219 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010206_00_000007_000035.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105776 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010206_00_000007_000035.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105758 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010206_00_000007_000035.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 105292 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_07_001014_001126.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 237267 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_07_001014_001126.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 246790 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_07_001014_001126.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 242855 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_07_001014_001126.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 240528 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_07_001014_001126.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 241499 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_07_001014_001126.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 241761 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050000_07_001014_001126.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 242999 ms elapsed
#
#
# Running CRF 7
# ...
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 240566 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050300_09_001789_001858.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 240978 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050300_09_001789_001858.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 239236 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050300_09_001789_001858.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 241173 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.16s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050300_09_001789_001858.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 241551 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_050300_09_001789_001858.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 241628 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010204_09_001285_001336.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106594 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010204_09_001285_001336.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106552 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010204_09_001285_001336.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107302 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010204_09_001285_001336.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107292 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010204_09_001285_001336.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107409 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010204_09_001285_001336.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106940 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010204_09_001285_001336.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106959 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010204_09_001285_001336.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 107062 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010204_09_001285_001336.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106915 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_010204_09_001285_001336.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 106877 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_00_000063_000085.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 250934 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.16s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_00_000063_000085.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 257520 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_00_000063_000085.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 253680 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_00_000063_000085.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 253812 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_00_000063_000085.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 252900 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_00_000063_000085.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 253582 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_00_000063_000085.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 254621 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_00_000063_000085.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 254306 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_00_000063_000085.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 252789 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_00_000063_000085.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 253840 ms elapsed
#
#
# Running CRF 0
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 0 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_04_000532_000622.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 252443 ms elapsed
#
#
# Running CRF 1
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 1 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_04_000532_000622.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 256630 ms elapsed
#
#
# Running CRF 2
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 2 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_04_000532_000622.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 252829 ms elapsed
#
#
# Running CRF 3
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 3 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_04_000532_000622.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 251241 ms elapsed
#
#
# Running CRF 4
#     Finished release [optimized] target(s) in 0.14s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 4 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_04_000532_000622.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 253718 ms elapsed
#
#
# Running CRF 5
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 5 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_04_000532_000622.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 253785 ms elapsed
#
#
# Running CRF 6
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 6 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_04_000532_000622.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 255170 ms elapsed
#
#
# Running CRF 7
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 7 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_04_000532_000622.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 255118 ms elapsed
#
#
# Running CRF 8
#     Finished release [optimized] target(s) in 0.16s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 8 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_04_000532_000622.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 255492 ms elapsed
#
#
# Running CRF 9
#     Finished release [optimized] target(s) in 0.15s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/evaluate_feature_detection_transcode --crf 9 --delta-t-max 76500 --frame-count-max 500 --input-filename /media/andrew/ExternalM2/VIRAT/videos_original/VIRAT_S_040000_04_000532_000622.mp4 --scale 0.5 --detect-features`
# ████████████████████████████████████████████████████████████████████████ 500/500
#
# 254349 ms elapsed
