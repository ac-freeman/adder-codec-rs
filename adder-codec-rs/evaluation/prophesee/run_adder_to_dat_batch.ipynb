# %%
import os

data_root = '/media/andrew/One Touch/HMNET_ADDER_data'

# for i in [0,1,2,3,6,9]:
for i in [0]:
    # look in ./gen${i} and get the file list
    input_directory_path = os.path.join(data_root, f'gen{i}')
    output_directory_path = os.path.join(data_root, f'gen{i}_dat')
    os.makedirs(output_directory_path, exist_ok=True)
    
    file_list = os.listdir(input_directory_path)
    file_list = [filename for filename in file_list if filename.endswith('.adder')]
    
    already_done_files = os.listdir(output_directory_path)
    print(already_done_files)
    
    for filename in file_list:
        
        # get filename without extension
        filename_out = filename.split('.')[0]+'.dat'
            
        input_file_path = os.path.join(input_directory_path, filename)
        output_file_path = os.path.join(output_directory_path, filename_out)
        
        if filename_out in already_done_files and os.path.getsize(output_file_path) > 100:
            print(f'Skipping {filename}')
            continue
        
        print(f'Processing {filename}')
        # adder-to-dvs --input "/home/andrew/Downloads/spinner.adder" --output-events "/home/andrew/Downloads/adder.dat" --output-video "/home/andrew/Downloads/adder_dvs.mp4" --show-display --fps 1000.0 --playback-slowdown 0.01
        # !cd /home/andrew/Code/adder-codec-rs/adder-to-dvs && cargo run --release -- --input "$input_file_path" --output-events "$output_file_path" --reorder
        print(f'Finished processing {input_file_path}')
    
    print("CRF", i, "done")
# Out:
# []
# Processing 17-04-13_15-05-43_1403500000_1463500000_td.adder
# warning: /home/andrew/Code/adder-codec-rs/Cargo.toml: unused manifest key: build
# warning: unused import: `BufWriter`
#  --> adder-codec-core/src/codec/compressed/stream.rs:3:15
#   |
# 3 | use std::io::{BufWriter, Cursor, Read, Seek, SeekFrom, Write};
#   |               ^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `crate::codec::Magic`
#  --> adder-codec-core/src/codec/decoder.rs:1:5
#   |
# 1 | use crate::codec::Magic;
#   |     ^^^^^^^^^^^^^^^^^^^
#
# warning: unused import: `crate::codec::encoder::Encoder`
#   --> adder-codec-core/src/codec/decoder.rs:11:5
#    |
# 11 | use crate::codec::encoder::Encoder;
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: constant `BLOCK_SIZE_AREA` is never used
#  --> adder-codec-core/src/codec/compressed/source_model/event_structure/mod.rs:8:11
#   |
# 8 | pub const BLOCK_SIZE_AREA: usize = BLOCK_SIZE * BLOCK_SIZE;
#   |           ^^^^^^^^^^^^^^^
#   |
#   = note: `#[warn(dead_code)]` on by default
#
# warning: variant `Compressed` is never constructed
#   --> adder-codec-core/src/codec/compressed/source_model/event_structure/event_adu.rs:42:5
#    |
# 41 | pub enum AduState {
#    |          -------- variant in this enum
# 42 |     Compressed,
#    |     ^^^^^^^^^^
#    |
#    = note: `AduState` has derived impls for the traits `Debug` and `Clone`, but these are intentionally ignored during dead code analysis
#
# warning: missing documentation for a function
#   --> adder-codec-core/src/lib.rs:49:1
#    |
# 49 | pub fn is_framed(source_camera: SourceCamera) -> bool {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/lib.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:195:1
#     |
# 195 | pub enum Mode {
#     | ^^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:207:1
#     |
# 207 | pub enum PixelMultiMode {
#     | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:208:5
#     |
# 208 |     Normal,
#     |     ^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:211:5
#     |
# 211 |     Collapse,
#     |     ^^^^^^^^
#
# warning: missing documentation for a module
#   --> adder-codec-core/src/codec/mod.rs:66:1
#    |
# 66 | pub mod rate_controller;
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/codec/mod.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:271:5
#     |
# 271 |     pub crf: Crf,
#     |     ^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#    --> adder-codec-core/src/codec/mod.rs:275:5
#     |
# 275 |     pub fn default(plane: PlaneSize) -> Self {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:293:9
#     |
# 293 |         target_event_rate: f64,
#     |         ^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:6:1
#   |
# 6 | pub const BLOCK_SIZE_BIG: usize = 64;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:8:1
#   |
# 8 | pub const BLOCK_SIZE_BIG_AREA: usize = BLOCK_SIZE_BIG * BLOCK_SIZE_BIG;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:10:1
#    |
# 10 | pub type DResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:11:1
#    |
# 11 | pub const DRESIDUAL_NO_EVENT: DResidual = 256;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:12:1
#    |
# 12 | pub const DRESIDUAL_SKIP_CUBE: DResidual = 257;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:13:1
#    |
# 13 | pub type TResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:18:5
#    |
# 18 |     pub fn new(n: usize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:76:5
#    |
# 76 |     pub fn len(&self) -> usize {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#    --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:112:1
#     |
# 112 | pub struct ValueError(pub usize);
#     | ^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:10:1
#    |
# 10 | pub struct FenwickModel {
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:48:5
#    |
# 48 |     pub fn set_context(&mut self, context: usize) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/decoder.rs:263:5
#     |
# 263 |     pub fn get_compression_type(&self) -> EncoderType {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#   --> adder-codec-core/src/codec/encoder.rs:36:5
#    |
# 36 |     pub options: EncoderOptions,
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/encoder.rs:299:5
#     |
# 299 |     pub fn get_options(&self) -> EncoderOptions {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:24:1
#    |
# 24 | pub struct Crf {
#    | ^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:38:1
#    |
# 38 | pub struct CrfParameters {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/rate_controller.rs:54:5
#    |
# 54 |     pub fn new(crf: Option<u8>, plane: PlaneSize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:69:5
#    |
# 69 |     pub fn override_c_thresh_baseline(&mut self, baseline: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:74:5
#    |
# 74 |     pub fn override_c_thresh_max(&mut self, max: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:79:5
#    |
# 79 |     pub fn override_c_increase_velocity(&mut self, velocity: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:84:5
#    |
# 84 |     pub fn override_feature_c_radius(&mut self, radius: u16) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:89:5
#    |
# 89 |     pub fn get_parameters(&self) -> &CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:93:5
#    |
# 93 |     pub fn get_parameters_mut(&mut self) -> &mut CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:97:5
#    |
# 97 |     pub fn get_quality(&self) -> Option<u8> {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: `adder-codec-core` (lib) generated 38 warnings (run `cargo fix --lib -p adder-codec-core` to apply 3 suggestions)
# warning: unused import: `DateTime`
#  --> adder-to-dvs/src/main.rs:3:14
#   |
# 3 | use chrono::{DateTime, Local};
#   |              ^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `std::time::Instant`
#   --> adder-to-dvs/src/main.rs:14:5
#    |
# 14 | use std::time::Instant;
#    |     ^^^^^^^^^^^^^^^^^^
#
# warning: unused variable: `frame_idx`
#    --> adder-to-dvs/src/main.rs:290:29
#     |
# 290 | ...                   let frame_idx = ((old_t + 1) / frame_length) as u...
#     |                           ^^^^^^^^^ help: if this is intentional, prefix it with an underscore: `_frame_idx`
#     |
#     = note: `#[warn(unused_variables)]` on by default
#
# warning: function `set_instant_dvs_pixel` is never used
#    --> adder-to-dvs/src/main.rs:389:4
#     |
# 389 | fn set_instant_dvs_pixel(
#     |    ^^^^^^^^^^^^^^^^^^^^^
#     |
#     = note: `#[warn(dead_code)]` on by default
#
# warning: `adder-to-dvs` (bin "adder-to-dvs") generated 4 warnings (run `cargo fix --bin "adder-to-dvs"` to apply 3 suggestions)
#     Finished release [optimized] target(s) in 0.09s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/adder-to-dvs --input '/media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-13_15-05-43_1403500000_1463500000_td.adder' --output-events '/media/andrew/One Touch/HMNET_ADDER_data/gen0_dat/17-04-13_15-05-43_1403500000_1463500000_td.dat' --reorder`
# [adder-to-dvs/src/main.rs:96] args.clone() = MyArgs {
#     input: "/media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-13_15-05-43_1403500000_1463500000_td.adder",
#     output_events: "/media/andrew/One Touch/HMNET_ADDER_data/gen0_dat/17-04-13_15-05-43_1403500000_1463500000_td.dat",
#     output_mode: Binary,
#     output_video: "",
#     fps: 100.0,
#     buffer_secs: 10.0,
#     theta: 0.01,
#     show_display: false,
#     playback_slowdown: 1.0,
#     reorder: true,
# }
# Transcoding ADΔER to DVS...0%Decompressed Adu in 281768696 ns
# Transcoding ADΔER to DVS...3%Decompressed Adu in 259718503 ns
# Transcoding ADΔER to DVS...6%Decompressed Adu in 333133466 ns
# Transcoding ADΔER to DVS...11%Decompressed Adu in 387932553 ns
# Transcoding ADΔER to DVS...17%Decompressed Adu in 584150560 ns
# Transcoding ADΔER to DVS...25%Decompressed Adu in 438622888 ns
# Transcoding ADΔER to DVS...32%Decompressed Adu in 357877601 ns
# Transcoding ADΔER to DVS...37%Decompressed Adu in 500927542 ns
# Transcoding ADΔER to DVS...44%Decompressed Adu in 614116724 ns
# Transcoding ADΔER to DVS...53%Decompressed Adu in 464648976 ns
# Transcoding ADΔER to DVS...59%Decompressed Adu in 442903715 ns
# Transcoding ADΔER to DVS...66%Decompressed Adu in 495938528 ns
# Transcoding ADΔER to DVS...73%Decompressed Adu in 466909824 ns
# Transcoding ADΔER to DVS...80%Decompressed Adu in 523404791 ns
# Transcoding ADΔER to DVS...87%Decompressed Adu in 463071783 ns
# Transcoding ADΔER to DVS...94%Decompressed Adu in 446890621 ns
# Transcoding ADΔER to DVS...101%Decompressed Adu in 534958890 ns
# Transcoding ADΔER to DVS...108%Decompressed Adu in 526746298 ns
# Transcoding ADΔER to DVS...116%Decompressed Adu in 541881891 ns
# Transcoding ADΔER to DVS...124%Decompressed Adu in 635871853 ns
# Transcoding ADΔER to DVS...133%Decompressed Adu in 680476454 ns
# Transcoding ADΔER to DVS...143%Decompressed Adu in 778564562 ns
# Transcoding ADΔER to DVS...154%Decompressed Adu in 777760266 ns
# Transcoding ADΔER to DVS...166%Decompressed Adu in 657616354 ns
# Transcoding ADΔER to DVS...175%Decompressed Adu in 502237795 ns
# Transcoding ADΔER to DVS...182%Decompressed Adu in 410173448 ns
# Transcoding ADΔER to DVS...188%Decompressed Adu in 324429509 ns
# Transcoding ADΔER to DVS...193%Decompressed Adu in 199113483 ns
# Transcoding ADΔER to DVS...196%Decompressed Adu in 114344700 ns
# Transcoding ADΔER to DVS...197%Decompressed Adu in 111861749 ns
# Transcoding ADΔER to DVS...199%Decompressed Adu in 113575633 ns
# Transcoding ADΔER to DVS...201%Decompressed Adu in 98767593 ns
# Transcoding ADΔER to DVS...202%Decompressed Adu in 103869509 ns
# Transcoding ADΔER to DVS...204%Decompressed Adu in 86650849 ns
# Transcoding ADΔER to DVS...205%Decompressed Adu in 118928440 ns
# Transcoding ADΔER to DVS...206%Decompressed Adu in 111376914 ns
# Transcoding ADΔER to DVS...208%Decompressed Adu in 94146181 ns
# Transcoding ADΔER to DVS...209%Decompressed Adu in 110334866 ns
# Transcoding ADΔER to DVS...211%Decompressed Adu in 119140542 ns
# Transcoding ADΔER to DVS...213%Decompressed Adu in 109111034 ns
# Transcoding ADΔER to DVS...214%Decompressed Adu in 115018665 ns
# Transcoding ADΔER to DVS...216%Decompressed Adu in 112574645 ns
# Transcoding ADΔER to DVS...218%Decompressed Adu in 87827128 ns
# Transcoding ADΔER to DVS...219%Decompressed Adu in 107364420 ns
# Transcoding ADΔER to DVS...220%Decompressed Adu in 131973794 ns
# Transcoding ADΔER to DVS...222%Decompressed Adu in 78119215 ns
# Transcoding ADΔER to DVS...223%Decompressed Adu in 119507015 ns
# Transcoding ADΔER to DVS...225%Decompressed Adu in 111392785 ns
# Transcoding ADΔER to DVS...226%Decompressed Adu in 143445926 ns
# Transcoding ADΔER to DVS...229%Decompressed Adu in 126830500 ns
# Transcoding ADΔER to DVS...230%Decompressed Adu in 183041500 ns
# Transcoding ADΔER to DVS...233%Decompressed Adu in 683980724 ns
# Transcoding ADΔER to DVS...243%Decompressed Adu in 304635796 ns
# Transcoding ADΔER to DVS...246%Decompressed Adu in 197418908 ns
# Transcoding ADΔER to DVS...249%Decompressed Adu in 251830574 ns
# Transcoding ADΔER to DVS...253%Decompressed Adu in 218706475 ns
# Transcoding ADΔER to DVS...256%Decompressed Adu in 284066725 ns
# Transcoding ADΔER to DVS...260%Decompressed Adu in 375507906 ns
# Transcoding ADΔER to DVS...265%Decompressed Adu in 268104677 ns
# Transcoding ADΔER to DVS...269%
#
# Finished!
# Finished processing /media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-13_15-05-43_1403500000_1463500000_td.adder
# Processing 17-04-14_14-59-17_122500000_182500000_td.adder
# warning: /home/andrew/Code/adder-codec-rs/Cargo.toml: unused manifest key: build
# warning: unused import: `BufWriter`
#  --> adder-codec-core/src/codec/compressed/stream.rs:3:15
#   |
# 3 | use std::io::{BufWriter, Cursor, Read, Seek, SeekFrom, Write};
#   |               ^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `crate::codec::Magic`
#  --> adder-codec-core/src/codec/decoder.rs:1:5
#   |
# 1 | use crate::codec::Magic;
#   |     ^^^^^^^^^^^^^^^^^^^
#
# warning: unused import: `crate::codec::encoder::Encoder`
#   --> adder-codec-core/src/codec/decoder.rs:11:5
#    |
# 11 | use crate::codec::encoder::Encoder;
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: constant `BLOCK_SIZE_AREA` is never used
#  --> adder-codec-core/src/codec/compressed/source_model/event_structure/mod.rs:8:11
#   |
# 8 | pub const BLOCK_SIZE_AREA: usize = BLOCK_SIZE * BLOCK_SIZE;
#   |           ^^^^^^^^^^^^^^^
#   |
#   = note: `#[warn(dead_code)]` on by default
#
# warning: variant `Compressed` is never constructed
#   --> adder-codec-core/src/codec/compressed/source_model/event_structure/event_adu.rs:42:5
#    |
# 41 | pub enum AduState {
#    |          -------- variant in this enum
# 42 |     Compressed,
#    |     ^^^^^^^^^^
#    |
#    = note: `AduState` has derived impls for the traits `Debug` and `Clone`, but these are intentionally ignored during dead code analysis
#
# warning: missing documentation for a function
#   --> adder-codec-core/src/lib.rs:49:1
#    |
# 49 | pub fn is_framed(source_camera: SourceCamera) -> bool {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/lib.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:195:1
#     |
# 195 | pub enum Mode {
#     | ^^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:207:1
#     |
# 207 | pub enum PixelMultiMode {
#     | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:208:5
#     |
# 208 |     Normal,
#     |     ^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:211:5
#     |
# 211 |     Collapse,
#     |     ^^^^^^^^
#
# warning: missing documentation for a module
#   --> adder-codec-core/src/codec/mod.rs:66:1
#    |
# 66 | pub mod rate_controller;
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/codec/mod.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:271:5
#     |
# 271 |     pub crf: Crf,
#     |     ^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#    --> adder-codec-core/src/codec/mod.rs:275:5
#     |
# 275 |     pub fn default(plane: PlaneSize) -> Self {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:293:9
#     |
# 293 |         target_event_rate: f64,
#     |         ^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:6:1
#   |
# 6 | pub const BLOCK_SIZE_BIG: usize = 64;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:8:1
#   |
# 8 | pub const BLOCK_SIZE_BIG_AREA: usize = BLOCK_SIZE_BIG * BLOCK_SIZE_BIG;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:10:1
#    |
# 10 | pub type DResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:11:1
#    |
# 11 | pub const DRESIDUAL_NO_EVENT: DResidual = 256;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:12:1
#    |
# 12 | pub const DRESIDUAL_SKIP_CUBE: DResidual = 257;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:13:1
#    |
# 13 | pub type TResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:18:5
#    |
# 18 |     pub fn new(n: usize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:76:5
#    |
# 76 |     pub fn len(&self) -> usize {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#    --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:112:1
#     |
# 112 | pub struct ValueError(pub usize);
#     | ^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:10:1
#    |
# 10 | pub struct FenwickModel {
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:48:5
#    |
# 48 |     pub fn set_context(&mut self, context: usize) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/decoder.rs:263:5
#     |
# 263 |     pub fn get_compression_type(&self) -> EncoderType {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#   --> adder-codec-core/src/codec/encoder.rs:36:5
#    |
# 36 |     pub options: EncoderOptions,
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/encoder.rs:299:5
#     |
# 299 |     pub fn get_options(&self) -> EncoderOptions {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:24:1
#    |
# 24 | pub struct Crf {
#    | ^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:38:1
#    |
# 38 | pub struct CrfParameters {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/rate_controller.rs:54:5
#    |
# 54 |     pub fn new(crf: Option<u8>, plane: PlaneSize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:69:5
#    |
# 69 |     pub fn override_c_thresh_baseline(&mut self, baseline: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:74:5
#    |
# 74 |     pub fn override_c_thresh_max(&mut self, max: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:79:5
#    |
# 79 |     pub fn override_c_increase_velocity(&mut self, velocity: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:84:5
#    |
# 84 |     pub fn override_feature_c_radius(&mut self, radius: u16) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:89:5
#    |
# 89 |     pub fn get_parameters(&self) -> &CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:93:5
#    |
# 93 |     pub fn get_parameters_mut(&mut self) -> &mut CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:97:5
#    |
# 97 |     pub fn get_quality(&self) -> Option<u8> {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: `adder-codec-core` (lib) generated 38 warnings (run `cargo fix --lib -p adder-codec-core` to apply 3 suggestions)
# warning: unused import: `DateTime`
#  --> adder-to-dvs/src/main.rs:3:14
#   |
# 3 | use chrono::{DateTime, Local};
#   |              ^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `std::time::Instant`
#   --> adder-to-dvs/src/main.rs:14:5
#    |
# 14 | use std::time::Instant;
#    |     ^^^^^^^^^^^^^^^^^^
#
# warning: unused variable: `frame_idx`
#    --> adder-to-dvs/src/main.rs:290:29
#     |
# 290 | ...                   let frame_idx = ((old_t + 1) / frame_length) as u...
#     |                           ^^^^^^^^^ help: if this is intentional, prefix it with an underscore: `_frame_idx`
#     |
#     = note: `#[warn(unused_variables)]` on by default
#
# warning: function `set_instant_dvs_pixel` is never used
#    --> adder-to-dvs/src/main.rs:389:4
#     |
# 389 | fn set_instant_dvs_pixel(
#     |    ^^^^^^^^^^^^^^^^^^^^^
#     |
#     = note: `#[warn(dead_code)]` on by default
#
# warning: `adder-to-dvs` (bin "adder-to-dvs") generated 4 warnings (run `cargo fix --bin "adder-to-dvs"` to apply 3 suggestions)
#     Finished release [optimized] target(s) in 0.09s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/adder-to-dvs --input '/media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-14_14-59-17_122500000_182500000_td.adder' --output-events '/media/andrew/One Touch/HMNET_ADDER_data/gen0_dat/17-04-14_14-59-17_122500000_182500000_td.dat' --reorder`
# [adder-to-dvs/src/main.rs:96] args.clone() = MyArgs {
#     input: "/media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-14_14-59-17_122500000_182500000_td.adder",
#     output_events: "/media/andrew/One Touch/HMNET_ADDER_data/gen0_dat/17-04-14_14-59-17_122500000_182500000_td.dat",
#     output_mode: Binary,
#     output_video: "",
#     fps: 100.0,
#     buffer_secs: 10.0,
#     theta: 0.01,
#     show_display: false,
#     playback_slowdown: 1.0,
#     reorder: true,
# }
# Transcoding ADΔER to DVS...0%Decompressed Adu in 1176196042 ns
# Transcoding ADΔER to DVS...3%Decompressed Adu in 1419271477 ns
# Transcoding ADΔER to DVS...8%Decompressed Adu in 1603987782 ns
# Transcoding ADΔER to DVS...13%Decompressed Adu in 1278701008 ns
# Transcoding ADΔER to DVS...18%Decompressed Adu in 1730949285 ns
# Transcoding ADΔER to DVS...24%Decompressed Adu in 1586110538 ns
# Transcoding ADΔER to DVS...31%Decompressed Adu in 1596053405 ns
# Transcoding ADΔER to DVS...37%Decompressed Adu in 1948434879 ns
# Transcoding ADΔER to DVS...44%Decompressed Adu in 1333627209 ns
# Transcoding ADΔER to DVS...49%Decompressed Adu in 1539793033 ns
# Transcoding ADΔER to DVS...55%Decompressed Adu in 1776640245 ns
# Transcoding ADΔER to DVS...62%Decompressed Adu in 1322186258 ns
# Transcoding ADΔER to DVS...67%Decompressed Adu in 1463021091 ns
# Transcoding ADΔER to DVS...73%Decompressed Adu in 1479768219 ns
# Transcoding ADΔER to DVS...79%Decompressed Adu in 1254347015 ns
# Transcoding ADΔER to DVS...84%Decompressed Adu in 1220981893 ns
# Transcoding ADΔER to DVS...88%Decompressed Adu in 1227199057 ns
# Transcoding ADΔER to DVS...93%Decompressed Adu in 1189098525 ns
# Transcoding ADΔER to DVS...98%Decompressed Adu in 1200342992 ns
# Transcoding ADΔER to DVS...102%Decompressed Adu in 1523912953 ns
# Transcoding ADΔER to DVS...108%Decompressed Adu in 1891056196 ns
# Transcoding ADΔER to DVS...114%Decompressed Adu in 1715598741 ns
# Transcoding ADΔER to DVS...121%Decompressed Adu in 1807641216 ns
# Transcoding ADΔER to DVS...127%Decompressed Adu in 1357529817 ns
# Transcoding ADΔER to DVS...133%Decompressed Adu in 1504413941 ns
# Transcoding ADΔER to DVS...138%Decompressed Adu in 1056478353 ns
# Transcoding ADΔER to DVS...142%Decompressed Adu in 1508566650 ns
# Transcoding ADΔER to DVS...148%Decompressed Adu in 1821262664 ns
# Transcoding ADΔER to DVS...155%Decompressed Adu in 2216315192 ns
# Transcoding ADΔER to DVS...162%Decompressed Adu in 1553931065 ns
# Transcoding ADΔER to DVS...168%Decompressed Adu in 1680979628 ns
# Transcoding ADΔER to DVS...175%Decompressed Adu in 1907776972 ns
# Transcoding ADΔER to DVS...182%Decompressed Adu in 1289470992 ns
# Transcoding ADΔER to DVS...187%Decompressed Adu in 1077191795 ns
# Transcoding ADΔER to DVS...191%Decompressed Adu in 1128325931 ns
# Transcoding ADΔER to DVS...195%Decompressed Adu in 1255985750 ns
# Transcoding ADΔER to DVS...200%Decompressed Adu in 1014331465 ns
# Transcoding ADΔER to DVS...203%Decompressed Adu in 951839058 ns
# Transcoding ADΔER to DVS...207%Decompressed Adu in 736148000 ns
# Transcoding ADΔER to DVS...210%Decompressed Adu in 246894401 ns
# Decompressed Adu in 73003898 ns
# Transcoding ADΔER to DVS...211%Decompressed Adu in 37420138 ns
# Decompressed Adu in 55264933 ns
# Decompressed Adu in 214183944 ns
# Transcoding ADΔER to DVS...212%Decompressed Adu in 553299542 ns
# Transcoding ADΔER to DVS...214%Decompressed Adu in 1030730808 ns
# Transcoding ADΔER to DVS...218%Decompressed Adu in 955721242 ns
# Transcoding ADΔER to DVS...221%Decompressed Adu in 639362214 ns
# Transcoding ADΔER to DVS...224%Decompressed Adu in 627242429 ns
# Transcoding ADΔER to DVS...226%Decompressed Adu in 787333819 ns
# Transcoding ADΔER to DVS...229%Decompressed Adu in 763647121 ns
# Transcoding ADΔER to DVS...232%Decompressed Adu in 771804423 ns
# Transcoding ADΔER to DVS...234%Decompressed Adu in 618193739 ns
# Transcoding ADΔER to DVS...237%Decompressed Adu in 537536443 ns
# Transcoding ADΔER to DVS...238%Decompressed Adu in 482557312 ns
# Transcoding ADΔER to DVS...240%Decompressed Adu in 408509256 ns
# Transcoding ADΔER to DVS...242%Decompressed Adu in 719127912 ns
# Transcoding ADΔER to DVS...244%Decompressed Adu in 563419040 ns
# Transcoding ADΔER to DVS...246%Decompressed Adu in 702303506 ns
# Transcoding ADΔER to DVS...249%
#
# Finished!
# Finished processing /media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-14_14-59-17_122500000_182500000_td.adder
# Processing 17-04-21_06-54-28_1891500000_1951500000_td.adder
# warning: /home/andrew/Code/adder-codec-rs/Cargo.toml: unused manifest key: build
# warning: unused import: `BufWriter`
#  --> adder-codec-core/src/codec/compressed/stream.rs:3:15
#   |
# 3 | use std::io::{BufWriter, Cursor, Read, Seek, SeekFrom, Write};
#   |               ^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `crate::codec::Magic`
#  --> adder-codec-core/src/codec/decoder.rs:1:5
#   |
# 1 | use crate::codec::Magic;
#   |     ^^^^^^^^^^^^^^^^^^^
#
# warning: unused import: `crate::codec::encoder::Encoder`
#   --> adder-codec-core/src/codec/decoder.rs:11:5
#    |
# 11 | use crate::codec::encoder::Encoder;
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: constant `BLOCK_SIZE_AREA` is never used
#  --> adder-codec-core/src/codec/compressed/source_model/event_structure/mod.rs:8:11
#   |
# 8 | pub const BLOCK_SIZE_AREA: usize = BLOCK_SIZE * BLOCK_SIZE;
#   |           ^^^^^^^^^^^^^^^
#   |
#   = note: `#[warn(dead_code)]` on by default
#
# warning: variant `Compressed` is never constructed
#   --> adder-codec-core/src/codec/compressed/source_model/event_structure/event_adu.rs:42:5
#    |
# 41 | pub enum AduState {
#    |          -------- variant in this enum
# 42 |     Compressed,
#    |     ^^^^^^^^^^
#    |
#    = note: `AduState` has derived impls for the traits `Debug` and `Clone`, but these are intentionally ignored during dead code analysis
#
# warning: missing documentation for a function
#   --> adder-codec-core/src/lib.rs:49:1
#    |
# 49 | pub fn is_framed(source_camera: SourceCamera) -> bool {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/lib.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:195:1
#     |
# 195 | pub enum Mode {
#     | ^^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:207:1
#     |
# 207 | pub enum PixelMultiMode {
#     | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:208:5
#     |
# 208 |     Normal,
#     |     ^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:211:5
#     |
# 211 |     Collapse,
#     |     ^^^^^^^^
#
# warning: missing documentation for a module
#   --> adder-codec-core/src/codec/mod.rs:66:1
#    |
# 66 | pub mod rate_controller;
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/codec/mod.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:271:5
#     |
# 271 |     pub crf: Crf,
#     |     ^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#    --> adder-codec-core/src/codec/mod.rs:275:5
#     |
# 275 |     pub fn default(plane: PlaneSize) -> Self {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:293:9
#     |
# 293 |         target_event_rate: f64,
#     |         ^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:6:1
#   |
# 6 | pub const BLOCK_SIZE_BIG: usize = 64;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:8:1
#   |
# 8 | pub const BLOCK_SIZE_BIG_AREA: usize = BLOCK_SIZE_BIG * BLOCK_SIZE_BIG;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:10:1
#    |
# 10 | pub type DResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:11:1
#    |
# 11 | pub const DRESIDUAL_NO_EVENT: DResidual = 256;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:12:1
#    |
# 12 | pub const DRESIDUAL_SKIP_CUBE: DResidual = 257;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:13:1
#    |
# 13 | pub type TResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:18:5
#    |
# 18 |     pub fn new(n: usize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:76:5
#    |
# 76 |     pub fn len(&self) -> usize {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#    --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:112:1
#     |
# 112 | pub struct ValueError(pub usize);
#     | ^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:10:1
#    |
# 10 | pub struct FenwickModel {
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:48:5
#    |
# 48 |     pub fn set_context(&mut self, context: usize) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/decoder.rs:263:5
#     |
# 263 |     pub fn get_compression_type(&self) -> EncoderType {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#   --> adder-codec-core/src/codec/encoder.rs:36:5
#    |
# 36 |     pub options: EncoderOptions,
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/encoder.rs:299:5
#     |
# 299 |     pub fn get_options(&self) -> EncoderOptions {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:24:1
#    |
# 24 | pub struct Crf {
#    | ^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:38:1
#    |
# 38 | pub struct CrfParameters {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/rate_controller.rs:54:5
#    |
# 54 |     pub fn new(crf: Option<u8>, plane: PlaneSize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:69:5
#    |
# 69 |     pub fn override_c_thresh_baseline(&mut self, baseline: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:74:5
#    |
# 74 |     pub fn override_c_thresh_max(&mut self, max: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:79:5
#    |
# 79 |     pub fn override_c_increase_velocity(&mut self, velocity: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:84:5
#    |
# 84 |     pub fn override_feature_c_radius(&mut self, radius: u16) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:89:5
#    |
# 89 |     pub fn get_parameters(&self) -> &CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:93:5
#    |
# 93 |     pub fn get_parameters_mut(&mut self) -> &mut CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:97:5
#    |
# 97 |     pub fn get_quality(&self) -> Option<u8> {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: `adder-codec-core` (lib) generated 38 warnings (run `cargo fix --lib -p adder-codec-core` to apply 3 suggestions)
# warning: unused import: `DateTime`
#  --> adder-to-dvs/src/main.rs:3:14
#   |
# 3 | use chrono::{DateTime, Local};
#   |              ^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `std::time::Instant`
#   --> adder-to-dvs/src/main.rs:14:5
#    |
# 14 | use std::time::Instant;
#    |     ^^^^^^^^^^^^^^^^^^
#
# warning: unused variable: `frame_idx`
#    --> adder-to-dvs/src/main.rs:290:29
#     |
# 290 | ...                   let frame_idx = ((old_t + 1) / frame_length) as u...
#     |                           ^^^^^^^^^ help: if this is intentional, prefix it with an underscore: `_frame_idx`
#     |
#     = note: `#[warn(unused_variables)]` on by default
#
# warning: function `set_instant_dvs_pixel` is never used
#    --> adder-to-dvs/src/main.rs:389:4
#     |
# 389 | fn set_instant_dvs_pixel(
#     |    ^^^^^^^^^^^^^^^^^^^^^
#     |
#     = note: `#[warn(dead_code)]` on by default
#
# warning: `adder-to-dvs` (bin "adder-to-dvs") generated 4 warnings (run `cargo fix --bin "adder-to-dvs"` to apply 3 suggestions)
#     Finished release [optimized] target(s) in 0.09s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/adder-to-dvs --input '/media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-21_06-54-28_1891500000_1951500000_td.adder' --output-events '/media/andrew/One Touch/HMNET_ADDER_data/gen0_dat/17-04-21_06-54-28_1891500000_1951500000_td.dat' --reorder`
# [adder-to-dvs/src/main.rs:96] args.clone() = MyArgs {
#     input: "/media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-21_06-54-28_1891500000_1951500000_td.adder",
#     output_events: "/media/andrew/One Touch/HMNET_ADDER_data/gen0_dat/17-04-21_06-54-28_1891500000_1951500000_td.dat",
#     output_mode: Binary,
#     output_video: "",
#     fps: 100.0,
#     buffer_secs: 10.0,
#     theta: 0.01,
#     show_display: false,
#     playback_slowdown: 1.0,
#     reorder: true,
# }
# Transcoding ADΔER to DVS...0%Decompressed Adu in 609315531 ns
# Transcoding ADΔER to DVS...1%Decompressed Adu in 336859536 ns
# Transcoding ADΔER to DVS...2%Decompressed Adu in 269094004 ns
# Transcoding ADΔER to DVS...3%Decompressed Adu in 672679067 ns
# Transcoding ADΔER to DVS...6%Decompressed Adu in 249715876 ns
# Transcoding ADΔER to DVS...7%Decompressed Adu in 131715912 ns
# Transcoding ADΔER to DVS...8%Decompressed Adu in 380309698 ns
# Transcoding ADΔER to DVS...9%Decompressed Adu in 318071102 ns
# Transcoding ADΔER to DVS...11%Decompressed Adu in 320230242 ns
# Transcoding ADΔER to DVS...12%Decompressed Adu in 1013933482 ns
# Transcoding ADΔER to DVS...17%Decompressed Adu in 485994272 ns
# Transcoding ADΔER to DVS...19%Decompressed Adu in 364297417 ns
# Transcoding ADΔER to DVS...21%Decompressed Adu in 1108957293 ns
# Transcoding ADΔER to DVS...26%Decompressed Adu in 397000514 ns
# Transcoding ADΔER to DVS...28%Decompressed Adu in 336845638 ns
# Transcoding ADΔER to DVS...29%Decompressed Adu in 426100089 ns
# Transcoding ADΔER to DVS...31%Decompressed Adu in 633524303 ns
# Transcoding ADΔER to DVS...34%Decompressed Adu in 574889410 ns
# Transcoding ADΔER to DVS...37%Decompressed Adu in 1572597539 ns
# Transcoding ADΔER to DVS...44%Decompressed Adu in 1333173264 ns
# Transcoding ADΔER to DVS...50%Decompressed Adu in 762166458 ns
# Transcoding ADΔER to DVS...53%Decompressed Adu in 577549504 ns
# Transcoding ADΔER to DVS...56%Decompressed Adu in 1180734031 ns
# Transcoding ADΔER to DVS...61%Decompressed Adu in 451885304 ns
# Transcoding ADΔER to DVS...63%Decompressed Adu in 711394515 ns
# Transcoding ADΔER to DVS...66%Decompressed Adu in 1010253749 ns
# Transcoding ADΔER to DVS...71%Decompressed Adu in 467932224 ns
# Transcoding ADΔER to DVS...73%Decompressed Adu in 427761554 ns
# Transcoding ADΔER to DVS...75%Decompressed Adu in 1062338655 ns
# Transcoding ADΔER to DVS...80%Decompressed Adu in 502833589 ns
# Transcoding ADΔER to DVS...82%Decompressed Adu in 578544432 ns
# Transcoding ADΔER to DVS...84%Decompressed Adu in 1320958738 ns
# Transcoding ADΔER to DVS...90%Decompressed Adu in 413068364 ns
# Transcoding ADΔER to DVS...92%Decompressed Adu in 1180774620 ns
# Transcoding ADΔER to DVS...98%Decompressed Adu in 608485074 ns
# Transcoding ADΔER to DVS...101%Decompressed Adu in 500372448 ns
# Transcoding ADΔER to DVS...103%Decompressed Adu in 1076963523 ns
# Transcoding ADΔER to DVS...108%Decompressed Adu in 436689371 ns
# Transcoding ADΔER to DVS...110%Decompressed Adu in 1061281276 ns
# Transcoding ADΔER to DVS...115%Decompressed Adu in 573326946 ns
# Transcoding ADΔER to DVS...118%Decompressed Adu in 1183631797 ns
# Transcoding ADΔER to DVS...123%Decompressed Adu in 1639815468 ns
# Transcoding ADΔER to DVS...131%Decompressed Adu in 960710777 ns
# Transcoding ADΔER to DVS...134%Decompressed Adu in 1613863021 ns
# Transcoding ADΔER to DVS...142%Decompressed Adu in 429160355 ns
# Transcoding ADΔER to DVS...143%Decompressed Adu in 832507494 ns
# Transcoding ADΔER to DVS...147%Decompressed Adu in 971990135 ns
# Transcoding ADΔER to DVS...152%Decompressed Adu in 1410069748 ns
# Transcoding ADΔER to DVS...158%Decompressed Adu in 2134485066 ns
# Transcoding ADΔER to DVS...168%Decompressed Adu in 2235411168 ns
# Transcoding ADΔER to DVS...178%Decompressed Adu in 1459032286 ns
# Transcoding ADΔER to DVS...185%Decompressed Adu in 1421958862 ns
# Transcoding ADΔER to DVS...192%Decompressed Adu in 1110928809 ns
# Transcoding ADΔER to DVS...197%Decompressed Adu in 1303920559 ns
# Transcoding ADΔER to DVS...203%Decompressed Adu in 1964404967 ns
# Transcoding ADΔER to DVS...213%Decompressed Adu in 2482966976 ns
# Transcoding ADΔER to DVS...224%Decompressed Adu in 2143320283 ns
# Transcoding ADΔER to DVS...234%Decompressed Adu in 2254641867 ns
# Transcoding ADΔER to DVS...245%Decompressed Adu in 2082951084 ns
# Transcoding ADΔER to DVS...256%
#
# Finished!
# Finished processing /media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-21_06-54-28_1891500000_1951500000_td.adder
# Processing 17-04-13_15-05-43_427500000_487500000_td.adder
# warning: /home/andrew/Code/adder-codec-rs/Cargo.toml: unused manifest key: build
# warning: unused import: `BufWriter`
#  --> adder-codec-core/src/codec/compressed/stream.rs:3:15
#   |
# 3 | use std::io::{BufWriter, Cursor, Read, Seek, SeekFrom, Write};
#   |               ^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `crate::codec::Magic`
#  --> adder-codec-core/src/codec/decoder.rs:1:5
#   |
# 1 | use crate::codec::Magic;
#   |     ^^^^^^^^^^^^^^^^^^^
#
# warning: unused import: `crate::codec::encoder::Encoder`
#   --> adder-codec-core/src/codec/decoder.rs:11:5
#    |
# 11 | use crate::codec::encoder::Encoder;
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: constant `BLOCK_SIZE_AREA` is never used
#  --> adder-codec-core/src/codec/compressed/source_model/event_structure/mod.rs:8:11
#   |
# 8 | pub const BLOCK_SIZE_AREA: usize = BLOCK_SIZE * BLOCK_SIZE;
#   |           ^^^^^^^^^^^^^^^
#   |
#   = note: `#[warn(dead_code)]` on by default
#
# warning: variant `Compressed` is never constructed
#   --> adder-codec-core/src/codec/compressed/source_model/event_structure/event_adu.rs:42:5
#    |
# 41 | pub enum AduState {
#    |          -------- variant in this enum
# 42 |     Compressed,
#    |     ^^^^^^^^^^
#    |
#    = note: `AduState` has derived impls for the traits `Debug` and `Clone`, but these are intentionally ignored during dead code analysis
#
# warning: missing documentation for a function
#   --> adder-codec-core/src/lib.rs:49:1
#    |
# 49 | pub fn is_framed(source_camera: SourceCamera) -> bool {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/lib.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:195:1
#     |
# 195 | pub enum Mode {
#     | ^^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:207:1
#     |
# 207 | pub enum PixelMultiMode {
#     | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:208:5
#     |
# 208 |     Normal,
#     |     ^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:211:5
#     |
# 211 |     Collapse,
#     |     ^^^^^^^^
#
# warning: missing documentation for a module
#   --> adder-codec-core/src/codec/mod.rs:66:1
#    |
# 66 | pub mod rate_controller;
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/codec/mod.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:271:5
#     |
# 271 |     pub crf: Crf,
#     |     ^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#    --> adder-codec-core/src/codec/mod.rs:275:5
#     |
# 275 |     pub fn default(plane: PlaneSize) -> Self {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:293:9
#     |
# 293 |         target_event_rate: f64,
#     |         ^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:6:1
#   |
# 6 | pub const BLOCK_SIZE_BIG: usize = 64;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:8:1
#   |
# 8 | pub const BLOCK_SIZE_BIG_AREA: usize = BLOCK_SIZE_BIG * BLOCK_SIZE_BIG;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:10:1
#    |
# 10 | pub type DResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:11:1
#    |
# 11 | pub const DRESIDUAL_NO_EVENT: DResidual = 256;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:12:1
#    |
# 12 | pub const DRESIDUAL_SKIP_CUBE: DResidual = 257;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:13:1
#    |
# 13 | pub type TResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:18:5
#    |
# 18 |     pub fn new(n: usize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:76:5
#    |
# 76 |     pub fn len(&self) -> usize {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#    --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:112:1
#     |
# 112 | pub struct ValueError(pub usize);
#     | ^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:10:1
#    |
# 10 | pub struct FenwickModel {
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:48:5
#    |
# 48 |     pub fn set_context(&mut self, context: usize) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/decoder.rs:263:5
#     |
# 263 |     pub fn get_compression_type(&self) -> EncoderType {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#   --> adder-codec-core/src/codec/encoder.rs:36:5
#    |
# 36 |     pub options: EncoderOptions,
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/encoder.rs:299:5
#     |
# 299 |     pub fn get_options(&self) -> EncoderOptions {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:24:1
#    |
# 24 | pub struct Crf {
# ...
# Transcoding ADΔER to DVS...132%Decompressed Adu in 1795234832 ns
# Transcoding ADΔER to DVS...137%Decompressed Adu in 1590528018 ns
# Transcoding ADΔER to DVS...142%Decompressed Adu in 1484165282 ns
# Transcoding ADΔER to DVS...146%Decompressed Adu in 1093657510 ns
# Transcoding ADΔER to DVS...149%Decompressed Adu in 1098262902 ns
# Transcoding ADΔER to DVS...152%Decompressed Adu in 1109205901 ns
# Transcoding ADΔER to DVS...155%Decompressed Adu in 1212525953 ns
# Transcoding ADΔER to DVS...158%Decompressed Adu in 1139006738 ns
# Transcoding ADΔER to DVS...161%Decompressed Adu in 1003319700 ns
# Transcoding ADΔER to DVS...164%Decompressed Adu in 1255534845 ns
# Transcoding ADΔER to DVS...167%Decompressed Adu in 1456778239 ns
# Transcoding ADΔER to DVS...172%Decompressed Adu in 1900673258 ns
# Transcoding ADΔER to DVS...177%Decompressed Adu in 1898200710 ns
# Transcoding ADΔER to DVS...182%Decompressed Adu in 2740189221 ns
# Transcoding ADΔER to DVS...190%Decompressed Adu in 5752373505 ns
# Transcoding ADΔER to DVS...205%Decompressed Adu in 3011842988 ns
# Transcoding ADΔER to DVS...213%Decompressed Adu in 2236495591 ns
# Transcoding ADΔER to DVS...220%Decompressed Adu in 1506150977 ns
# Transcoding ADΔER to DVS...224%Decompressed Adu in 1428629230 ns
# Transcoding ADΔER to DVS...228%Decompressed Adu in 1965288341 ns
# Transcoding ADΔER to DVS...233%Decompressed Adu in 2477940528 ns
# Transcoding ADΔER to DVS...240%Decompressed Adu in 1926929241 ns
# Transcoding ADΔER to DVS...246%Decompressed Adu in 1562780335 ns
# Transcoding ADΔER to DVS...249%Decompressed Adu in 762321675 ns
# Transcoding ADΔER to DVS...251%Decompressed Adu in 711392818 ns
# Transcoding ADΔER to DVS...253%Decompressed Adu in 1406204616 ns
# Transcoding ADΔER to DVS...257%Decompressed Adu in 1754451098 ns
# Transcoding ADΔER to DVS...262%Decompressed Adu in 1895649009 ns
# Transcoding ADΔER to DVS...268%
#
# Finished!
# Finished processing /media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-21_09-48-10_3355500000_3415500000_td.adder
# Processing 17-04-21_06-54-28_1647500000_1707500000_td.adder
# warning: /home/andrew/Code/adder-codec-rs/Cargo.toml: unused manifest key: build
# warning: unused import: `BufWriter`
#  --> adder-codec-core/src/codec/compressed/stream.rs:3:15
#   |
# 3 | use std::io::{BufWriter, Cursor, Read, Seek, SeekFrom, Write};
#   |               ^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `crate::codec::Magic`
#  --> adder-codec-core/src/codec/decoder.rs:1:5
#   |
# 1 | use crate::codec::Magic;
#   |     ^^^^^^^^^^^^^^^^^^^
#
# warning: unused import: `crate::codec::encoder::Encoder`
#   --> adder-codec-core/src/codec/decoder.rs:11:5
#    |
# 11 | use crate::codec::encoder::Encoder;
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: constant `BLOCK_SIZE_AREA` is never used
#  --> adder-codec-core/src/codec/compressed/source_model/event_structure/mod.rs:8:11
#   |
# 8 | pub const BLOCK_SIZE_AREA: usize = BLOCK_SIZE * BLOCK_SIZE;
#   |           ^^^^^^^^^^^^^^^
#   |
#   = note: `#[warn(dead_code)]` on by default
#
# warning: variant `Compressed` is never constructed
#   --> adder-codec-core/src/codec/compressed/source_model/event_structure/event_adu.rs:42:5
#    |
# 41 | pub enum AduState {
#    |          -------- variant in this enum
# 42 |     Compressed,
#    |     ^^^^^^^^^^
#    |
#    = note: `AduState` has derived impls for the traits `Debug` and `Clone`, but these are intentionally ignored during dead code analysis
#
# warning: missing documentation for a function
#   --> adder-codec-core/src/lib.rs:49:1
#    |
# 49 | pub fn is_framed(source_camera: SourceCamera) -> bool {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/lib.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:195:1
#     |
# 195 | pub enum Mode {
#     | ^^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:207:1
#     |
# 207 | pub enum PixelMultiMode {
#     | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:208:5
#     |
# 208 |     Normal,
#     |     ^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:211:5
#     |
# 211 |     Collapse,
#     |     ^^^^^^^^
#
# warning: missing documentation for a module
#   --> adder-codec-core/src/codec/mod.rs:66:1
#    |
# 66 | pub mod rate_controller;
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/codec/mod.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:271:5
#     |
# 271 |     pub crf: Crf,
#     |     ^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#    --> adder-codec-core/src/codec/mod.rs:275:5
#     |
# 275 |     pub fn default(plane: PlaneSize) -> Self {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:293:9
#     |
# 293 |         target_event_rate: f64,
#     |         ^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:6:1
#   |
# 6 | pub const BLOCK_SIZE_BIG: usize = 64;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:8:1
#   |
# 8 | pub const BLOCK_SIZE_BIG_AREA: usize = BLOCK_SIZE_BIG * BLOCK_SIZE_BIG;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:10:1
#    |
# 10 | pub type DResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:11:1
#    |
# 11 | pub const DRESIDUAL_NO_EVENT: DResidual = 256;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:12:1
#    |
# 12 | pub const DRESIDUAL_SKIP_CUBE: DResidual = 257;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:13:1
#    |
# 13 | pub type TResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:18:5
#    |
# 18 |     pub fn new(n: usize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:76:5
#    |
# 76 |     pub fn len(&self) -> usize {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#    --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:112:1
#     |
# 112 | pub struct ValueError(pub usize);
#     | ^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:10:1
#    |
# 10 | pub struct FenwickModel {
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:48:5
#    |
# 48 |     pub fn set_context(&mut self, context: usize) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/decoder.rs:263:5
#     |
# 263 |     pub fn get_compression_type(&self) -> EncoderType {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#   --> adder-codec-core/src/codec/encoder.rs:36:5
#    |
# 36 |     pub options: EncoderOptions,
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/encoder.rs:299:5
#     |
# 299 |     pub fn get_options(&self) -> EncoderOptions {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:24:1
#    |
# 24 | pub struct Crf {
#    | ^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:38:1
#    |
# 38 | pub struct CrfParameters {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/rate_controller.rs:54:5
#    |
# 54 |     pub fn new(crf: Option<u8>, plane: PlaneSize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:69:5
#    |
# 69 |     pub fn override_c_thresh_baseline(&mut self, baseline: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:74:5
#    |
# 74 |     pub fn override_c_thresh_max(&mut self, max: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:79:5
#    |
# 79 |     pub fn override_c_increase_velocity(&mut self, velocity: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:84:5
#    |
# 84 |     pub fn override_feature_c_radius(&mut self, radius: u16) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:89:5
#    |
# 89 |     pub fn get_parameters(&self) -> &CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:93:5
#    |
# 93 |     pub fn get_parameters_mut(&mut self) -> &mut CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:97:5
#    |
# 97 |     pub fn get_quality(&self) -> Option<u8> {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: `adder-codec-core` (lib) generated 38 warnings (run `cargo fix --lib -p adder-codec-core` to apply 3 suggestions)
# warning: unused import: `DateTime`
#  --> adder-to-dvs/src/main.rs:3:14
#   |
# 3 | use chrono::{DateTime, Local};
#   |              ^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `std::time::Instant`
#   --> adder-to-dvs/src/main.rs:14:5
#    |
# 14 | use std::time::Instant;
#    |     ^^^^^^^^^^^^^^^^^^
#
# warning: unused variable: `frame_idx`
#    --> adder-to-dvs/src/main.rs:290:29
#     |
# 290 | ...                   let frame_idx = ((old_t + 1) / frame_length) as u...
#     |                           ^^^^^^^^^ help: if this is intentional, prefix it with an underscore: `_frame_idx`
#     |
#     = note: `#[warn(unused_variables)]` on by default
#
# warning: function `set_instant_dvs_pixel` is never used
#    --> adder-to-dvs/src/main.rs:389:4
#     |
# 389 | fn set_instant_dvs_pixel(
#     |    ^^^^^^^^^^^^^^^^^^^^^
#     |
#     = note: `#[warn(dead_code)]` on by default
#
# warning: `adder-to-dvs` (bin "adder-to-dvs") generated 4 warnings (run `cargo fix --bin "adder-to-dvs"` to apply 3 suggestions)
#     Finished release [optimized] target(s) in 0.09s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/adder-to-dvs --input '/media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-21_06-54-28_1647500000_1707500000_td.adder' --output-events '/media/andrew/One Touch/HMNET_ADDER_data/gen0_dat/17-04-21_06-54-28_1647500000_1707500000_td.dat' --reorder`
# [adder-to-dvs/src/main.rs:96] args.clone() = MyArgs {
#     input: "/media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-21_06-54-28_1647500000_1707500000_td.adder",
#     output_events: "/media/andrew/One Touch/HMNET_ADDER_data/gen0_dat/17-04-21_06-54-28_1647500000_1707500000_td.dat",
#     output_mode: Binary,
#     output_video: "",
#     fps: 100.0,
#     buffer_secs: 10.0,
#     theta: 0.01,
#     show_display: false,
#     playback_slowdown: 1.0,
#     reorder: true,
# }
# Transcoding ADΔER to DVS...0%Decompressed Adu in 800303018 ns
# Transcoding ADΔER to DVS...0%Decompressed Adu in 239398615 ns
# Transcoding ADΔER to DVS...1%Decompressed Adu in 260086500 ns
# Transcoding ADΔER to DVS...2%Decompressed Adu in 289584532 ns
# Transcoding ADΔER to DVS...3%Decompressed Adu in 404944092 ns
# Transcoding ADΔER to DVS...5%Decompressed Adu in 332492971 ns
# Transcoding ADΔER to DVS...7%Decompressed Adu in 241767171 ns
# Transcoding ADΔER to DVS...8%Decompressed Adu in 262658058 ns
# Transcoding ADΔER to DVS...10%Decompressed Adu in 511334824 ns
# Transcoding ADΔER to DVS...12%Decompressed Adu in 859777999 ns
# Transcoding ADΔER to DVS...15%Decompressed Adu in 757832205 ns
# Transcoding ADΔER to DVS...19%Decompressed Adu in 753806832 ns
# Transcoding ADΔER to DVS...21%Decompressed Adu in 1223251477 ns
# Transcoding ADΔER to DVS...25%Decompressed Adu in 852703671 ns
# Transcoding ADΔER to DVS...29%Decompressed Adu in 1055574726 ns
# Transcoding ADΔER to DVS...34%Decompressed Adu in 1038710402 ns
# Transcoding ADΔER to DVS...39%Decompressed Adu in 715614025 ns
# Transcoding ADΔER to DVS...42%Decompressed Adu in 1293490504 ns
# Transcoding ADΔER to DVS...49%Decompressed Adu in 495423859 ns
# Transcoding ADΔER to DVS...52%Decompressed Adu in 612042034 ns
# Transcoding ADΔER to DVS...55%Decompressed Adu in 728854349 ns
# Transcoding ADΔER to DVS...58%Decompressed Adu in 1526036584 ns
# Transcoding ADΔER to DVS...66%Decompressed Adu in 885146885 ns
# Transcoding ADΔER to DVS...70%Decompressed Adu in 1474237997 ns
# Transcoding ADΔER to DVS...78%Decompressed Adu in 812031938 ns
# Transcoding ADΔER to DVS...82%Decompressed Adu in 860756088 ns
# Transcoding ADΔER to DVS...87%Decompressed Adu in 731682831 ns
# Transcoding ADΔER to DVS...90%Decompressed Adu in 1116399220 ns
# Transcoding ADΔER to DVS...96%Decompressed Adu in 1311181336 ns
# Transcoding ADΔER to DVS...103%Decompressed Adu in 870660337 ns
# Transcoding ADΔER to DVS...107%Decompressed Adu in 1159505522 ns
# Transcoding ADΔER to DVS...113%Decompressed Adu in 1361766690 ns
# Transcoding ADΔER to DVS...120%Decompressed Adu in 679978265 ns
# Transcoding ADΔER to DVS...124%Decompressed Adu in 887383140 ns
# Transcoding ADΔER to DVS...128%Decompressed Adu in 1385227206 ns
# Transcoding ADΔER to DVS...135%Decompressed Adu in 708984992 ns
# Transcoding ADΔER to DVS...139%Decompressed Adu in 1158763302 ns
# Transcoding ADΔER to DVS...145%Decompressed Adu in 927354156 ns
# Transcoding ADΔER to DVS...150%Decompressed Adu in 821707053 ns
# Transcoding ADΔER to DVS...154%Decompressed Adu in 1050305618 ns
# Transcoding ADΔER to DVS...159%Decompressed Adu in 968320604 ns
# Transcoding ADΔER to DVS...164%Decompressed Adu in 933953147 ns
# Transcoding ADΔER to DVS...169%Decompressed Adu in 1197329434 ns
# Transcoding ADΔER to DVS...175%Decompressed Adu in 1645965712 ns
# Transcoding ADΔER to DVS...184%Decompressed Adu in 1094239118 ns
# Transcoding ADΔER to DVS...189%Decompressed Adu in 917051994 ns
# Transcoding ADΔER to DVS...194%Decompressed Adu in 1227683226 ns
# Transcoding ADΔER to DVS...200%Decompressed Adu in 1518039377 ns
# Transcoding ADΔER to DVS...207%Decompressed Adu in 1266336708 ns
# Transcoding ADΔER to DVS...214%Decompressed Adu in 596714976 ns
# Transcoding ADΔER to DVS...217%Decompressed Adu in 1063096698 ns
# Transcoding ADΔER to DVS...222%Decompressed Adu in 1138069826 ns
# Transcoding ADΔER to DVS...228%Decompressed Adu in 827373395 ns
# Transcoding ADΔER to DVS...232%Decompressed Adu in 751430055 ns
# Transcoding ADΔER to DVS...236%Decompressed Adu in 652886148 ns
# Transcoding ADΔER to DVS...239%Decompressed Adu in 544913739 ns
# Transcoding ADΔER to DVS...242%Decompressed Adu in 506642542 ns
# Transcoding ADΔER to DVS...244%Decompressed Adu in 431082907 ns
# Transcoding ADΔER to DVS...246%Decompressed Adu in 714265679 ns
# Transcoding ADΔER to DVS...250%
#
# Finished!
# Finished processing /media/andrew/One Touch/HMNET_ADDER_data/gen0/17-04-21_06-54-28_1647500000_1707500000_td.adder
# CRF 0 done
