# %%
import os

data_root = '/media/andrew/One Touch/HMNET_ADDER_data'

for i in [1,2,3,6,9]:
    # look in ./gen${i} and get the file list
    input_directory_path = os.path.join(data_root, f'gen{i}')
    output_directory_path = os.path.join(data_root, f'gen{i}_dat')
    os.makedirs(output_directory_path, exist_ok=True)
    
    file_list = os.listdir(input_directory_path)
    file_list = [filename for filename in file_list if filename.endswith('.adder')]
    
    already_done_files = os.listdir(output_directory_path)
    print(already_done_files)
    
    for filename in file_list:
        
        # get filename without extension
        filename_out = filename.split('.')[0]+'.dat'
            
        input_file_path = os.path.join(input_directory_path, filename)
        output_file_path = os.path.join(output_directory_path, filename_out)
        
        if filename_out in already_done_files and os.path.getsize(output_file_path) > 100:
            print(f'Skipping {filename}')
            continue
        
        print(f'Processing {filename}')
        # adder-to-dvs --input "/home/andrew/Downloads/spinner.adder" --output-events "/home/andrew/Downloads/adder.dat" --output-video "/home/andrew/Downloads/adder_dvs.mp4" --show-display --fps 1000.0 --playback-slowdown 0.01
        # !cd /home/andrew/Code/adder-codec-rs/adder-to-dvs && cargo run --release -- --input "$input_file_path" --output-events "$output_file_path"
        print(f'Finished processing {input_file_path}')
    
    print("CRF", i, "done")
# Out:
# []
# Processing 17-04-13_15-05-43_1403500000_1463500000_td.adder
# warning: /home/andrew/Code/adder-codec-rs/Cargo.toml: unused manifest key: build
#    Compiling autocfg v1.1.0
#    Compiling proc-macro2 v1.0.69
#    Compiling unicode-ident v1.0.12
#    Compiling libc v0.2.149
#    Compiling cfg-if v1.0.0
#    Compiling glob v0.3.1
#    Compiling version_check v0.9.4
#    Compiling memchr v2.6.4
#    Compiling minimal-lexical v0.2.1
#    Compiling crossbeam-utils v0.8.17
#    Compiling syn v1.0.109
#    Compiling regex-syntax v0.8.2
#    Compiling serde v1.0.190
#    Compiling bindgen v0.64.0
#    Compiling scopeguard v1.2.0
#    Compiling libloading v0.7.4        ] 0/156: syn(build.rs), libc(build...
#    Compiling lazy_static v1.4.0       ] 1/156: syn(build.rs), libc(build...
#    Compiling shlex v1.2.0             ] 2/156: syn(build.rs), libc(build...
#    Compiling bitflags v1.3.2          ] 3/156: syn(build.rs), libc(build...
#    Compiling peeking_take_while v0.1.2] 4/156: bitflags, syn(build.rs), ...
#    Compiling lazycell v1.3.0          ] 5/156: peeking_take_while, syn(b...
#    Compiling rustc-hash v1.1.0        ] 6/156: peeking_take_while, syn(b...
#    Compiling rayon-core v1.12.0       ] 7/156: syn(build.rs), libc(build...
#    Compiling cc v1.0.79               ] 8/156: rayon-core(build.rs), syn...
#    Compiling pkg-config v0.3.27       ] 9/156: rayon-core(build.rs), syn...
#    Compiling once_cell v1.18.0       ] 10/156: rayon-core(build.rs), syn...
#    Compiling thiserror v1.0.50       ] 11/156: once_cell, rayon-core(bui...
#    Compiling either v1.9.0           ] 12/156: once_cell, rayon-core(bui...
#    Compiling tinyvec_macros v0.1.1   ] 14/156: once_cell, rayon-core(bui...
#    Compiling num-traits v0.2.17      ] 16/156: once_cell, rayon-core(bui...
#    Compiling memoffset v0.9.0        ] 17/156: once_cell, rayon-core(bui...
#    Compiling num-integer v0.1.45     ] 18/156: once_cell, rayon-core(bui...
#    Compiling crossbeam-epoch v0.9.15 ] 22/156: once_cell, rayon-core(bui...
#    Compiling clang-sys v1.6.1        ] 25/156: once_cell, rayon-core(bui...
#    Compiling matrixmultiply v0.3.8   ] 29/156: thiserror(build.rs), memc...
#    Compiling tinyvec v1.6.0          ] 31/156: thiserror(build.rs), memc...
#    Compiling nom v7.1.3              ] 32/156: thiserror(build.rs), memc...
#    Compiling indexmap v1.9.3         ] 40/156: matrixmultiply(build), cr...
#    Compiling rustfft v6.1.0          ] 41/156: matrixmultiply(build), in...
#    Compiling ahash v0.8.6
#    Compiling quote v1.0.33           ] 43/156: indexmap(build.rs), memch...
#    Compiling strength_reduce v0.2.4  ] 44/156: indexmap(build.rs), memch...
#    Compiling rawpointer v0.2.1       ] 45/156: indexmap(build.rs), memch...
#    Compiling syn v2.0.38             ] 49/156: rawpointer, indexmap(buil...
#    Compiling utf8parse v0.2.1        ] 52/156: indexmap(build.rs), syn, ...
#    Compiling num_cpus v1.16.0        ] 58/156: matrixmultiply, syn, inde...
#    Compiling getrandom v0.2.10       ] 59/156: matrixmultiply, syn, inde...
#    Compiling anstyle-parse v0.2.3    ] 60/156: matrixmultiply, syn, inde...
#    Compiling priority-queue v1.3.2   ] 61/156: matrixmultiply, syn, clan...
#    Compiling percent-encoding v2.3.0 ] 62/156: matrixmultiply, syn, clan...
#    Compiling crossbeam-deque v0.8.3  ] 63/156: matrixmultiply, syn, clan...
#    Compiling rand_core v0.6.4        ] 64/156: matrixmultiply, syn, clan...
#    Compiling anstyle-query v1.0.2    ] 65/156: matrixmultiply, syn, rand...
#    Compiling unicode-bidi v0.3.13    ] 66/156: matrixmultiply, syn, rand...
#    Compiling ppv-lite86 v0.2.17      ] 67/156: matrixmultiply, syn, rand...
#    Compiling anstyle v1.0.4          ] 68/156: matrixmultiply, syn, rand...
#    Compiling unicode-normalization v0.1.22156: matrixmultiply, syn, rand...
#    Compiling ffmpeg-next v6.1.0      ] 71/156: matrixmultiply, syn, rand...
#    Compiling zerocopy v0.7.31        ] 72/156: matrixmultiply, syn, rand...
#    Compiling hashbrown v0.12.3       ] 73/156: matrixmultiply, syn, rand...
#    Compiling colorchoice v1.0.0      ] 74/156: matrixmultiply, hashbrown...
#    Compiling serde_json v1.0.107     ] 75/156: matrixmultiply, hashbrown...
#    Compiling anstream v0.6.5         ] 76/156: matrixmultiply, hashbrown...
#    Compiling rand_chacha v0.3.1      ] 78/156: matrixmultiply, hashbrown...
#    Compiling form_urlencoded v1.2.0  ] 80/156: matrixmultiply, hashbrown...
#    Compiling tracing-core v0.1.32    ] 82/156: serde_json(build), matrix...
#    Compiling regex-automata v0.4.3   ] 84/156: matrixmultiply, hashbrown...
#    Compiling num-complex v0.4.4      ] 85/156: matrixmultiply, hashbrown...
#    Compiling rayon v1.8.0            ] 86/156: num-complex, matrixmultip...
#    Compiling idna v0.4.0>            ] 87/156: num-complex, matrixmultip...
#    Compiling cexpr v0.6.0            ] 89/156: num-complex, matrixmultip...
#    Compiling primal-check v0.3.3     ] 90/156: num-complex, matrixmultip...
#    Compiling transpose v0.2.2        ] 91/156: num-complex, matrixmultip...
#    Compiling itoa v1.0.9=>           ] 92/156: num-complex, matrixmultip...
#    Compiling strsim v0.10.0          ] 93/156: num-complex, matrixmultip...
#    Compiling clap_lex v0.6.0         ] 94/156: num-complex, matrixmultip...
#    Compiling ryu v1.0.15==>          ] 96/156: num-complex, matrixmultip...
#    Compiling heck v0.4.1==>          ] 97/156: num-complex, matrixmultip...
#    Compiling bitstream-io v1.10.0    ] 99/156: matrixmultiply, syn, ryu,...
#    Compiling pin-project-lite v0.2.13 101/156: matrixmultiply, syn, ryu,...
#    Compiling clap_builder v4.4.11   ] 102/156: matrixmultiply, syn, idna...
#    Compiling url v2.4.1===>         ] 104/156: matrixmultiply, clap_buil...
#    Compiling hashbrown v0.13.2      ] 105/156: matrixmultiply, clap_buil...
#    Compiling float-cmp v0.9.0       ] 106/156: matrixmultiply, clap_buil...
#    Compiling rand v0.8.5===>        ] 107/156: matrixmultiply, clap_buil...
#    Compiling itertools v0.10.5      ] 108/156: matrixmultiply, clap_buil...
#    Compiling iana-time-zone v0.1.58 ] 109/156: matrixmultiply, clap_buil...
#    Compiling fenwick v2.0.1>        ] 110/156: matrixmultiply, clap_buil...
#    Compiling numquant v0.2.0        ] 111/156: matrixmultiply, clap_buil...
#    Compiling seq-macro v0.3.5       ] 112/156: matrixmultiply, clap_buil...
#    Compiling chrono v0.4.31=>       ] 113/156: matrixmultiply, clap_buil...
#    Compiling regex v1.10.2==>       ] 115/156: matrixmultiply, clap_buil...
#    Compiling serde_derive v1.0.190  ] 126/156: bindgen, clap_builder, sy...
#    Compiling thiserror-impl v1.0.50 ] 127/156: bindgen, clap_builder, ch...
#    Compiling tracing-attributes v0.1.2727/156: thiserror-impl, bindgen, ...
#    Compiling clap_derive v4.4.7     ] 127/156: thiserror-impl, bindgen, ...
#    Compiling enum_dispatch v0.3.12  ] 127/156: thiserror-impl, bindgen, ...
#    Compiling arithmetic-coding-core-adder-dep v0.3.0 (/home/andrew/Code/adder-codec-rs/arithmetic-coding-adder-dep/arithmetic-coding-core-adder-dep)
#    Compiling arithmetic-coding-adder-dep v0.3.2 (/home/andrew/Code/adder-codec-rs/arithmetic-coding-adder-dep)
#    Compiling tracing v0.1.40===>    ] 134/156: bindgen, tracing-attribut...
#    Compiling clap v4.4.11======>    ] 137/156: bindgen, clap_derive, ser...
#    Compiling rustdct v0.7.1=====>   ] 139/156: bindgen, serde_derive, ru...
#    Compiling ffmpeg-sys-next v6.1.0 ] 141/156: bindgen, serde, rustdct
#    Compiling ndarray v0.15.6=====>  ] 144/156: ffmpeg-sys-next(build), s...
#    Compiling serde_bytes v0.11.12
#    Compiling bincode v1.3.3
#    Compiling adder-codec-core v0.3.2 (/home/andrew/Code/adder-codec-rs/adder-codec-core)
# warning: unused import: `BufWriter`r-codec-core, ffmpeg-...
#  --> adder-codec-core/src/codec/compressed/stream.rs:3:15
#   |
# 3 | use std::io::{BufWriter, Cursor, Read, Seek, SeekFrom, Write};
#   |               ^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `crate::codec::Magic`re, ffmpeg-...
#  --> adder-codec-core/src/codec/decoder.rs:1:5
#   |
# 1 | use crate::codec::Magic;
#   |     ^^^^^^^^^^^^^^^^^^^
#
# warning: unused import: `crate::codec::encoder::Encoder`...
#   --> adder-codec-core/src/codec/decoder.rs:11:5
#    |
# 11 | use crate::codec::encoder::Encoder;
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: constant `BLOCK_SIZE_AREA` is never usedffmpeg-...
#  --> adder-codec-core/src/codec/compressed/source_model/event_structure/mod.rs:8:11
#   |
# 8 | pub const BLOCK_SIZE_AREA: usize = BLOCK_SIZE * BLOCK_SIZE;
#   |           ^^^^^^^^^^^^^^^
#   |
#   = note: `#[warn(dead_code)]` on by default
#
# warning: variant `Compressed` is never constructed
#   --> adder-codec-core/src/codec/compressed/source_model/event_structure/event_adu.rs:42:5
#    |
# 41 | pub enum AduState {
#    |          -------- variant in this enum
# 42 |     Compressed,
#    |     ^^^^^^^^^^
#    |
#    = note: `AduState` has derived impls for the traits `Debug` and `Clone`, but these are intentionally ignored during dead code analysis
#
# warning: missing documentation for a functionre, ffmpeg-...
#   --> adder-codec-core/src/lib.rs:49:1
#    |
# 49 | pub fn is_framed(source_camera: SourceCamera) -> bool {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/lib.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for an enum-core, ffmpeg-...
#    --> adder-codec-core/src/lib.rs:195:1
#     |
# 195 | pub enum Mode {
#     | ^^^^^^^^^^^^^
#
# warning: missing documentation for an enum-core, ffmpeg-...
#    --> adder-codec-core/src/lib.rs:207:1
#     |
# 207 | pub enum PixelMultiMode {
#     | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:208:5
#     |
# 208 |     Normal,
#     |     ^^^^^^
#
# warning: missing documentation for a variantore, ffmpeg-...
#    --> adder-codec-core/src/lib.rs:211:5
#     |
# 211 |     Collapse,
#     |     ^^^^^^^^
#
# warning: missing documentation for a modulecore, ffmpeg-...
#   --> adder-codec-core/src/codec/mod.rs:66:1
#    |
# 66 | pub mod rate_controller;
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/codec/mod.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:271:5
#     |
# 271 |     pub crf: Crf,
#     |     ^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#    --> adder-codec-core/src/codec/mod.rs:275:5
#     |
# 275 |     pub fn default(plane: PlaneSize) -> Self {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct fieldffmpeg-...
#    --> adder-codec-core/src/codec/mod.rs:293:9
#     |
# 293 |         target_event_rate: f64,
#     |         ^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constantre, ffmpeg-...
#  --> adder-codec-core/src/codec/compressed/mod.rs:6:1
#   |
# 6 | pub const BLOCK_SIZE_BIG: usize = 64;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:8:1
#   |
# 8 | pub const BLOCK_SIZE_BIG_AREA: usize = BLOCK_SIZE_BIG * BLOCK_SIZE_BIG;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias, ffmpeg-...
#   --> adder-codec-core/src/codec/compressed/mod.rs:10:1
#    |
# 10 | pub type DResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constantre, ffmpeg-...
#   --> adder-codec-core/src/codec/compressed/mod.rs:11:1
#    |
# 11 | pub const DRESIDUAL_NO_EVENT: DResidual = 256;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constantre, ffmpeg-...
#   --> adder-codec-core/src/codec/compressed/mod.rs:12:1
#    |
# 12 | pub const DRESIDUAL_SKIP_CUBE: DResidual = 257;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:13:1
#    |
# 13 | pub type TResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function..
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:18:5
#    |
# 18 |     pub fn new(n: usize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a methodcore, ffmpeg-...
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:76:5
#    |
# 76 |     pub fn len(&self) -> usize {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a structcore, ffmpeg-...
#    --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:112:1
#     |
# 112 | pub struct ValueError(pub usize);
#     | ^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a structcore, ffmpeg-...
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:10:1
#    |
# 10 | pub struct FenwickModel {
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a methodcore, ffmpeg-...
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:48:5
#    |
# 48 |     pub fn set_context(&mut self, context: usize) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a methodcore, ffmpeg-...
#    --> adder-codec-core/src/codec/decoder.rs:263:5
#     |
# 263 |     pub fn get_compression_type(&self) -> EncoderType {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#   --> adder-codec-core/src/codec/encoder.rs:36:5
#    |
# 36 |     pub options: EncoderOptions,
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a methodcore, ffmpeg-...
#    --> adder-codec-core/src/codec/encoder.rs:299:5
#     |
# 299 |     pub fn get_options(&self) -> EncoderOptions {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a structcore, ffmpeg-...
#   --> adder-codec-core/src/codec/rate_controller.rs:24:1
#    |
# 24 | pub struct Crf {
#    | ^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:38:1
#    |
# 38 | pub struct CrfParameters {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/rate_controller.rs:54:5
#    |
# 54 |     pub fn new(crf: Option<u8>, plane: PlaneSize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a methodcore, ffmpeg-...
#   --> adder-codec-core/src/codec/rate_controller.rs:69:5
#    |
# 69 |     pub fn override_c_thresh_baseline(&mut self, baseline: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:74:5
#    |
# 74 |     pub fn override_c_thresh_max(&mut self, max: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:79:5
#    |
# 79 |     pub fn override_c_increase_velocity(&mut self, velocity: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a methodcore, ffmpeg-...
#   --> adder-codec-core/src/codec/rate_controller.rs:84:5
#    |
# 84 |     pub fn override_feature_c_radius(&mut self, radius: u16) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a methodcore, ffmpeg-...
#   --> adder-codec-core/src/codec/rate_controller.rs:89:5
#    |
# 89 |     pub fn get_parameters(&self) -> &CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:93:5
#    |
# 93 |     pub fn get_parameters_mut(&mut self) -> &mut CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:97:5
#    |
# 97 |     pub fn get_quality(&self) -> Option<u8> {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: `adder-codec-core` (lib) generated 38 warnings (run `cargo fix --lib -p adder-codec-core` to apply 3 suggestions)
#    Compiling video-rs v0.5.0======> ] 153/156: ffmpeg-next
#    Compiling adder-to-dvs v0.2.7 (/home/andrew/Code/adder-codec-rs/adder-to-dvs)
# warning: unused import: `DateTime`er-to-dvs(bin)
#  --> adder-to-dvs/src/main.rs:3:14
#   |
# 3 | use chrono::{DateTime, Local};
#   |              ^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `std::time::Instant`bin)
#   --> adder-to-dvs/src/main.rs:14:5
#    |
# 14 | use std::time::Instant;
#    |     ^^^^^^^^^^^^^^^^^^
#
# warning: unused variable: `frame_idx`to-dvs(bin)
#    --> adder-to-dvs/src/main.rs:290:29
#     |
# 290 | ...                   let frame_idx = ((old_t + 1) / frame_length) as u...
#     |                           ^^^^^^^^^ help: if this is intentional, prefix it with an underscore: `_frame_idx`
#     |
#     = note: `#[warn(unused_variables)]` on by default
#
# warning: function `set_instant_dvs_pixel` is never used
#    --> adder-to-dvs/src/main.rs:389:4
#     |
# 389 | fn set_instant_dvs_pixel(
#     |    ^^^^^^^^^^^^^^^^^^^^^
#     |
#     = note: `#[warn(dead_code)]` on by default
#
# warning: `adder-to-dvs` (bin "adder-to-dvs") generated 4 warnings (run `cargo fix --bin "adder-to-dvs"` to apply 3 suggestions)
#     Finished release [optimized] target(s) in 18.79s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/adder-to-dvs --input '/media/andrew/One Touch/HMNET_ADDER_data/gen1/17-04-13_15-05-43_1403500000_1463500000_td.adder' --output-events '/media/andrew/One Touch/HMNET_ADDER_data/gen1_dat/17-04-13_15-05-43_1403500000_1463500000_td.dat'`
# [adder-to-dvs/src/main.rs:96] args.clone() = MyArgs {
#     input: "/media/andrew/One Touch/HMNET_ADDER_data/gen1/17-04-13_15-05-43_1403500000_1463500000_td.adder",
#     output_events: "/media/andrew/One Touch/HMNET_ADDER_data/gen1_dat/17-04-13_15-05-43_1403500000_1463500000_td.dat",
#     output_mode: Binary,
#     output_video: "",
#     fps: 100.0,
#     buffer_secs: 10.0,
#     theta: 0.01,
#     show_display: false,
#     playback_slowdown: 1.0,
#     reorder: false,
# }
# Transcoding ADΔER to DVS...0%Decompressed Adu in 296732304 ns
# Transcoding ADΔER to DVS...3%Decompressed Adu in 265166512 ns
# Transcoding ADΔER to DVS...6%Decompressed Adu in 360694594 ns
# Transcoding ADΔER to DVS...11%Decompressed Adu in 403417487 ns
# Transcoding ADΔER to DVS...17%Decompressed Adu in 586717548 ns
# Transcoding ADΔER to DVS...25%Decompressed Adu in 439998079 ns
# Transcoding ADΔER to DVS...32%Decompressed Adu in 351286257 ns
# Transcoding ADΔER to DVS...37%Decompressed Adu in 498660924 ns
# Transcoding ADΔER to DVS...44%Decompressed Adu in 616074298 ns
# Transcoding ADΔER to DVS...53%Decompressed Adu in 464110033 ns
# Transcoding ADΔER to DVS...59%Decompressed Adu in 446515794 ns
# Transcoding ADΔER to DVS...66%Decompressed Adu in 503834197 ns
# Transcoding ADΔER to DVS...73%Decompressed Adu in 469519319 ns
# Transcoding ADΔER to DVS...80%Decompressed Adu in 516952131 ns
# Transcoding ADΔER to DVS...87%Decompressed Adu in 461464588 ns
# Transcoding ADΔER to DVS...94%Decompressed Adu in 445166402 ns
# Transcoding ADΔER to DVS...101%Decompressed Adu in 535068415 ns
# Transcoding ADΔER to DVS...108%Decompressed Adu in 556528262 ns
# Transcoding ADΔER to DVS...116%Decompressed Adu in 542086134 ns
# Transcoding ADΔER to DVS...124%Decompressed Adu in 636778337 ns
# Transcoding ADΔER to DVS...133%Decompressed Adu in 680023086 ns
# Transcoding ADΔER to DVS...143%Decompressed Adu in 813845476 ns
# Transcoding ADΔER to DVS...154%Decompressed Adu in 791559958 ns
# Transcoding ADΔER to DVS...166%Decompressed Adu in 670904833 ns
# Transcoding ADΔER to DVS...175%Decompressed Adu in 504771316 ns
# Transcoding ADΔER to DVS...182%Decompressed Adu in 409476617 ns
# Transcoding ADΔER to DVS...188%Decompressed Adu in 323792588 ns
# Transcoding ADΔER to DVS...193%Decompressed Adu in 199698588 ns
# Transcoding ADΔER to DVS...196%Decompressed Adu in 115049058 ns
# Transcoding ADΔER to DVS...197%Decompressed Adu in 112177788 ns
# Transcoding ADΔER to DVS...199%Decompressed Adu in 110882567 ns
# Transcoding ADΔER to DVS...201%Decompressed Adu in 97151277 ns
# Transcoding ADΔER to DVS...202%Decompressed Adu in 170468341 ns
# Transcoding ADΔER to DVS...204%Decompressed Adu in 85799360 ns
# Transcoding ADΔER to DVS...205%Decompressed Adu in 117097880 ns
# Transcoding ADΔER to DVS...206%Decompressed Adu in 111096720 ns
# Transcoding ADΔER to DVS...208%Decompressed Adu in 93515800 ns
# Transcoding ADΔER to DVS...209%Decompressed Adu in 109577344 ns
# Transcoding ADΔER to DVS...211%Decompressed Adu in 118225210 ns
# Transcoding ADΔER to DVS...213%Decompressed Adu in 108232369 ns
# Transcoding ADΔER to DVS...214%Decompressed Adu in 114756265 ns
# Transcoding ADΔER to DVS...216%Decompressed Adu in 112213300 ns
# Transcoding ADΔER to DVS...218%Decompressed Adu in 87874164 ns
# Transcoding ADΔER to DVS...219%Decompressed Adu in 107964037 ns
# Transcoding ADΔER to DVS...220%Decompressed Adu in 132227173 ns
# Transcoding ADΔER to DVS...222%Decompressed Adu in 77771230 ns
# Transcoding ADΔER to DVS...223%Decompressed Adu in 118148810 ns
# Transcoding ADΔER to DVS...225%Decompressed Adu in 112083917 ns
# Transcoding ADΔER to DVS...226%Decompressed Adu in 143309495 ns
# Transcoding ADΔER to DVS...229%Decompressed Adu in 126870589 ns
# Transcoding ADΔER to DVS...230%Decompressed Adu in 173626663 ns
# Transcoding ADΔER to DVS...233%Decompressed Adu in 664745731 ns
# Transcoding ADΔER to DVS...243%Decompressed Adu in 254248342 ns
# Transcoding ADΔER to DVS...246%Decompressed Adu in 196580618 ns
# Transcoding ADΔER to DVS...249%Decompressed Adu in 241111158 ns
# Transcoding ADΔER to DVS...253%Decompressed Adu in 216397737 ns
# Transcoding ADΔER to DVS...256%Decompressed Adu in 283103926 ns
# Transcoding ADΔER to DVS...260%Decompressed Adu in 348023905 ns
# Transcoding ADΔER to DVS...265%Decompressed Adu in 266056774 ns
# Transcoding ADΔER to DVS...269%
#
# Finished!
# Finished processing /media/andrew/One Touch/HMNET_ADDER_data/gen1/17-04-13_15-05-43_1403500000_1463500000_td.adder
# Processing 17-04-14_14-59-17_122500000_182500000_td.adder
# warning: /home/andrew/Code/adder-codec-rs/Cargo.toml: unused manifest key: build
# warning: unused import: `BufWriter`
#  --> adder-codec-core/src/codec/compressed/stream.rs:3:15
#   |
# 3 | use std::io::{BufWriter, Cursor, Read, Seek, SeekFrom, Write};
#   |               ^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `crate::codec::Magic`
#  --> adder-codec-core/src/codec/decoder.rs:1:5
#   |
# 1 | use crate::codec::Magic;
#   |     ^^^^^^^^^^^^^^^^^^^
#
# warning: unused import: `crate::codec::encoder::Encoder`
#   --> adder-codec-core/src/codec/decoder.rs:11:5
#    |
# 11 | use crate::codec::encoder::Encoder;
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: constant `BLOCK_SIZE_AREA` is never used
#  --> adder-codec-core/src/codec/compressed/source_model/event_structure/mod.rs:8:11
#   |
# 8 | pub const BLOCK_SIZE_AREA: usize = BLOCK_SIZE * BLOCK_SIZE;
#   |           ^^^^^^^^^^^^^^^
#   |
#   = note: `#[warn(dead_code)]` on by default
#
# warning: variant `Compressed` is never constructed
#   --> adder-codec-core/src/codec/compressed/source_model/event_structure/event_adu.rs:42:5
#    |
# 41 | pub enum AduState {
#    |          -------- variant in this enum
# 42 |     Compressed,
#    |     ^^^^^^^^^^
#    |
#    = note: `AduState` has derived impls for the traits `Debug` and `Clone`, but these are intentionally ignored during dead code analysis
#
# warning: missing documentation for a function
#   --> adder-codec-core/src/lib.rs:49:1
#    |
# 49 | pub fn is_framed(source_camera: SourceCamera) -> bool {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/lib.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:195:1
#     |
# 195 | pub enum Mode {
#     | ^^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:207:1
#     |
# 207 | pub enum PixelMultiMode {
#     | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:208:5
#     |
# 208 |     Normal,
#     |     ^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:211:5
#     |
# 211 |     Collapse,
#     |     ^^^^^^^^
#
# warning: missing documentation for a module
#   --> adder-codec-core/src/codec/mod.rs:66:1
#    |
# 66 | pub mod rate_controller;
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/codec/mod.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:271:5
#     |
# 271 |     pub crf: Crf,
#     |     ^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#    --> adder-codec-core/src/codec/mod.rs:275:5
#     |
# 275 |     pub fn default(plane: PlaneSize) -> Self {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:293:9
#     |
# 293 |         target_event_rate: f64,
#     |         ^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:6:1
#   |
# 6 | pub const BLOCK_SIZE_BIG: usize = 64;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:8:1
#   |
# 8 | pub const BLOCK_SIZE_BIG_AREA: usize = BLOCK_SIZE_BIG * BLOCK_SIZE_BIG;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:10:1
#    |
# 10 | pub type DResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:11:1
#    |
# 11 | pub const DRESIDUAL_NO_EVENT: DResidual = 256;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:12:1
#    |
# 12 | pub const DRESIDUAL_SKIP_CUBE: DResidual = 257;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:13:1
#    |
# 13 | pub type TResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:18:5
#    |
# 18 |     pub fn new(n: usize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:76:5
#    |
# 76 |     pub fn len(&self) -> usize {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#    --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:112:1
#     |
# 112 | pub struct ValueError(pub usize);
#     | ^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:10:1
#    |
# 10 | pub struct FenwickModel {
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:48:5
#    |
# 48 |     pub fn set_context(&mut self, context: usize) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/decoder.rs:263:5
#     |
# 263 |     pub fn get_compression_type(&self) -> EncoderType {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#   --> adder-codec-core/src/codec/encoder.rs:36:5
#    |
# 36 |     pub options: EncoderOptions,
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/encoder.rs:299:5
#     |
# 299 |     pub fn get_options(&self) -> EncoderOptions {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:24:1
#    |
# 24 | pub struct Crf {
#    | ^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:38:1
#    |
# 38 | pub struct CrfParameters {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/rate_controller.rs:54:5
#    |
# 54 |     pub fn new(crf: Option<u8>, plane: PlaneSize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:69:5
#    |
# 69 |     pub fn override_c_thresh_baseline(&mut self, baseline: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:74:5
#    |
# 74 |     pub fn override_c_thresh_max(&mut self, max: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:79:5
#    |
# 79 |     pub fn override_c_increase_velocity(&mut self, velocity: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:84:5
#    |
# 84 |     pub fn override_feature_c_radius(&mut self, radius: u16) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:89:5
#    |
# 89 |     pub fn get_parameters(&self) -> &CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:93:5
#    |
# 93 |     pub fn get_parameters_mut(&mut self) -> &mut CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:97:5
#    |
# 97 |     pub fn get_quality(&self) -> Option<u8> {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: `adder-codec-core` (lib) generated 38 warnings (run `cargo fix --lib -p adder-codec-core` to apply 3 suggestions)
# warning: unused import: `DateTime`
#  --> adder-to-dvs/src/main.rs:3:14
#   |
# 3 | use chrono::{DateTime, Local};
#   |              ^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `std::time::Instant`
#   --> adder-to-dvs/src/main.rs:14:5
#    |
# 14 | use std::time::Instant;
#    |     ^^^^^^^^^^^^^^^^^^
#
# warning: unused variable: `frame_idx`
#    --> adder-to-dvs/src/main.rs:290:29
#     |
# 290 | ...                   let frame_idx = ((old_t + 1) / frame_length) as u...
#     |                           ^^^^^^^^^ help: if this is intentional, prefix it with an underscore: `_frame_idx`
#     |
#     = note: `#[warn(unused_variables)]` on by default
#
# warning: function `set_instant_dvs_pixel` is never used
#    --> adder-to-dvs/src/main.rs:389:4
#     |
# 389 | fn set_instant_dvs_pixel(
#     |    ^^^^^^^^^^^^^^^^^^^^^
#     |
#     = note: `#[warn(dead_code)]` on by default
#
# warning: `adder-to-dvs` (bin "adder-to-dvs") generated 4 warnings (run `cargo fix --bin "adder-to-dvs"` to apply 3 suggestions)
#     Finished release [optimized] target(s) in 0.09s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/adder-to-dvs --input '/media/andrew/One Touch/HMNET_ADDER_data/gen1/17-04-14_14-59-17_122500000_182500000_td.adder' --output-events '/media/andrew/One Touch/HMNET_ADDER_data/gen1_dat/17-04-14_14-59-17_122500000_182500000_td.dat'`
# [adder-to-dvs/src/main.rs:96] args.clone() = MyArgs {
#     input: "/media/andrew/One Touch/HMNET_ADDER_data/gen1/17-04-14_14-59-17_122500000_182500000_td.adder",
#     output_events: "/media/andrew/One Touch/HMNET_ADDER_data/gen1_dat/17-04-14_14-59-17_122500000_182500000_td.dat",
#     output_mode: Binary,
#     output_video: "",
#     fps: 100.0,
#     buffer_secs: 10.0,
#     theta: 0.01,
#     show_display: false,
#     playback_slowdown: 1.0,
#     reorder: false,
# }
# Transcoding ADΔER to DVS...0%Decompressed Adu in 1159967199 ns
# Transcoding ADΔER to DVS...3%Decompressed Adu in 1421554646 ns
# Transcoding ADΔER to DVS...8%Decompressed Adu in 1272415842 ns
# Transcoding ADΔER to DVS...13%Decompressed Adu in 1226932831 ns
# Transcoding ADΔER to DVS...18%Decompressed Adu in 1707192937 ns
# Transcoding ADΔER to DVS...24%Decompressed Adu in 1603106211 ns
# Transcoding ADΔER to DVS...31%Decompressed Adu in 1595319533 ns
# Transcoding ADΔER to DVS...37%Decompressed Adu in 1956922844 ns
# Transcoding ADΔER to DVS...44%Decompressed Adu in 1352991551 ns
# Transcoding ADΔER to DVS...49%Decompressed Adu in 1543915349 ns
# Transcoding ADΔER to DVS...55%Decompressed Adu in 1749357235 ns
# Transcoding ADΔER to DVS...62%Decompressed Adu in 1305080513 ns
# Transcoding ADΔER to DVS...67%Decompressed Adu in 1477718447 ns
# Transcoding ADΔER to DVS...73%Decompressed Adu in 1491233483 ns
# Transcoding ADΔER to DVS...79%Decompressed Adu in 1258707353 ns
# Transcoding ADΔER to DVS...84%Decompressed Adu in 1226534236 ns
# Transcoding ADΔER to DVS...88%Decompressed Adu in 1695138355 ns
# Transcoding ADΔER to DVS...93%Decompressed Adu in 1210576655 ns
# Transcoding ADΔER to DVS...98%Decompressed Adu in 1200980727 ns
# Transcoding ADΔER to DVS...102%Decompressed Adu in 1509729802 ns
# Transcoding ADΔER to DVS...108%Decompressed Adu in 1567325976 ns
# Transcoding ADΔER to DVS...114%Decompressed Adu in 1728688026 ns
# Transcoding ADΔER to DVS...121%Decompressed Adu in 1818821993 ns
# Transcoding ADΔER to DVS...127%Decompressed Adu in 1351862769 ns
# Transcoding ADΔER to DVS...133%Decompressed Adu in 1513381401 ns
# Transcoding ADΔER to DVS...138%Decompressed Adu in 1055519228 ns
# Transcoding ADΔER to DVS...142%Decompressed Adu in 1507562789 ns
# Transcoding ADΔER to DVS...148%Decompressed Adu in 1832265778 ns
# Transcoding ADΔER to DVS...155%Decompressed Adu in 1857208141 ns
# Transcoding ADΔER to DVS...162%Decompressed Adu in 1524263350 ns
# Transcoding ADΔER to DVS...168%Decompressed Adu in 1676814819 ns
# Transcoding ADΔER to DVS...175%Decompressed Adu in 1893441279 ns
# Transcoding ADΔER to DVS...182%Decompressed Adu in 1237639068 ns
# Transcoding ADΔER to DVS...187%Decompressed Adu in 982784252 ns
# Transcoding ADΔER to DVS...191%Decompressed Adu in 1081703215 ns
# Transcoding ADΔER to DVS...195%Decompressed Adu in 1152201581 ns
# Transcoding ADΔER to DVS...200%Decompressed Adu in 1709619423 ns
# Transcoding ADΔER to DVS...203%Decompressed Adu in 918108195 ns
# Transcoding ADΔER to DVS...207%Decompressed Adu in 671350868 ns
# Transcoding ADΔER to DVS...210%Decompressed Adu in 242889417 ns
# Decompressed Adu in 71221163 ns
# Transcoding ADΔER to DVS...211%Decompressed Adu in 36248187 ns
# Decompressed Adu in 56312872 ns
# Decompressed Adu in 209674330 ns
# Transcoding ADΔER to DVS...212%Decompressed Adu in 551947415 ns
# Transcoding ADΔER to DVS...214%Decompressed Adu in 1024693036 ns
# Transcoding ADΔER to DVS...218%Decompressed Adu in 940809704 ns
# Transcoding ADΔER to DVS...221%Decompressed Adu in 634575665 ns
# Transcoding ADΔER to DVS...224%Decompressed Adu in 618180399 ns
# Transcoding ADΔER to DVS...226%Decompressed Adu in 746658702 ns
# Transcoding ADΔER to DVS...229%Decompressed Adu in 729396168 ns
# Transcoding ADΔER to DVS...232%Decompressed Adu in 698275061 ns
# Transcoding ADΔER to DVS...234%Decompressed Adu in 556119988 ns
# Transcoding ADΔER to DVS...237%Decompressed Adu in 487192669 ns
# Transcoding ADΔER to DVS...238%Decompressed Adu in 482160997 ns
# Transcoding ADΔER to DVS...240%Decompressed Adu in 410530048 ns
# Transcoding ADΔER to DVS...242%Decompressed Adu in 716573877 ns
# Transcoding ADΔER to DVS...244%Decompressed Adu in 562370431 ns
# Transcoding ADΔER to DVS...246%Decompressed Adu in 701135570 ns
# Transcoding ADΔER to DVS...249%
#
# Finished!
# Finished processing /media/andrew/One Touch/HMNET_ADDER_data/gen1/17-04-14_14-59-17_122500000_182500000_td.adder
# Processing 17-04-21_06-54-28_1891500000_1951500000_td.adder
# warning: /home/andrew/Code/adder-codec-rs/Cargo.toml: unused manifest key: build
# warning: unused import: `BufWriter`
#  --> adder-codec-core/src/codec/compressed/stream.rs:3:15
#   |
# 3 | use std::io::{BufWriter, Cursor, Read, Seek, SeekFrom, Write};
#   |               ^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `crate::codec::Magic`
#  --> adder-codec-core/src/codec/decoder.rs:1:5
#   |
# 1 | use crate::codec::Magic;
#   |     ^^^^^^^^^^^^^^^^^^^
#
# warning: unused import: `crate::codec::encoder::Encoder`
#   --> adder-codec-core/src/codec/decoder.rs:11:5
#    |
# 11 | use crate::codec::encoder::Encoder;
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: constant `BLOCK_SIZE_AREA` is never used
#  --> adder-codec-core/src/codec/compressed/source_model/event_structure/mod.rs:8:11
#   |
# 8 | pub const BLOCK_SIZE_AREA: usize = BLOCK_SIZE * BLOCK_SIZE;
#   |           ^^^^^^^^^^^^^^^
#   |
#   = note: `#[warn(dead_code)]` on by default
#
# warning: variant `Compressed` is never constructed
#   --> adder-codec-core/src/codec/compressed/source_model/event_structure/event_adu.rs:42:5
#    |
# 41 | pub enum AduState {
#    |          -------- variant in this enum
# 42 |     Compressed,
#    |     ^^^^^^^^^^
#    |
#    = note: `AduState` has derived impls for the traits `Debug` and `Clone`, but these are intentionally ignored during dead code analysis
#
# warning: missing documentation for a function
#   --> adder-codec-core/src/lib.rs:49:1
#    |
# 49 | pub fn is_framed(source_camera: SourceCamera) -> bool {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/lib.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:195:1
#     |
# 195 | pub enum Mode {
#     | ^^^^^^^^^^^^^
#
# warning: missing documentation for an enum
#    --> adder-codec-core/src/lib.rs:207:1
#     |
# 207 | pub enum PixelMultiMode {
#     | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:208:5
#     |
# 208 |     Normal,
#     |     ^^^^^^
#
# warning: missing documentation for a variant
#    --> adder-codec-core/src/lib.rs:211:5
#     |
# 211 |     Collapse,
#     |     ^^^^^^^^
#
# warning: missing documentation for a module
#   --> adder-codec-core/src/codec/mod.rs:66:1
#    |
# 66 | pub mod rate_controller;
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#    |
# note: the lint level is defined here
#   --> adder-codec-core/src/codec/mod.rs:1:9
#    |
# 1  | #![warn(missing_docs)]
#    |         ^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:271:5
#     |
# 271 |     pub crf: Crf,
#     |     ^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#    --> adder-codec-core/src/codec/mod.rs:275:5
#     |
# 275 |     pub fn default(plane: PlaneSize) -> Self {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#    --> adder-codec-core/src/codec/mod.rs:293:9
#     |
# 293 |         target_event_rate: f64,
#     |         ^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:6:1
#   |
# 6 | pub const BLOCK_SIZE_BIG: usize = 64;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#  --> adder-codec-core/src/codec/compressed/mod.rs:8:1
#   |
# 8 | pub const BLOCK_SIZE_BIG_AREA: usize = BLOCK_SIZE_BIG * BLOCK_SIZE_BIG;
#   | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:10:1
#    |
# 10 | pub type DResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:11:1
#    |
# 11 | pub const DRESIDUAL_NO_EVENT: DResidual = 256;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a constant
#   --> adder-codec-core/src/codec/compressed/mod.rs:12:1
#    |
# 12 | pub const DRESIDUAL_SKIP_CUBE: DResidual = 257;
#    | ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a type alias
#   --> adder-codec-core/src/codec/compressed/mod.rs:13:1
#    |
# 13 | pub type TResidual = i16;
#    | ^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:18:5
#    |
# 18 |     pub fn new(n: usize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:76:5
#    |
# 76 |     pub fn len(&self) -> usize {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#    --> adder-codec-core/src/codec/compressed/fenwick/mod.rs:112:1
#     |
# 112 | pub struct ValueError(pub usize);
#     | ^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:10:1
#    |
# 10 | pub struct FenwickModel {
#    | ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/compressed/fenwick/context_switching.rs:48:5
#    |
# 48 |     pub fn set_context(&mut self, context: usize) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/decoder.rs:263:5
#     |
# 263 |     pub fn get_compression_type(&self) -> EncoderType {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct field
#   --> adder-codec-core/src/codec/encoder.rs:36:5
#    |
# 36 |     pub options: EncoderOptions,
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#    --> adder-codec-core/src/codec/encoder.rs:299:5
#     |
# 299 |     pub fn get_options(&self) -> EncoderOptions {
#     |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:24:1
#    |
# 24 | pub struct Crf {
#    | ^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:38:1
#    |
# 38 | pub struct CrfParameters {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/rate_controller.rs:54:5
#    |
# 54 |     pub fn new(crf: Option<u8>, plane: PlaneSize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:69:5
#    |
# 69 |     pub fn override_c_thresh_baseline(&mut self, baseline: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:74:5
#    |
# 74 |     pub fn override_c_thresh_max(&mut self, max: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:79:5
#    |
# 79 |     pub fn override_c_increase_velocity(&mut self, velocity: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:84:5
#    |
# 84 |     pub fn override_feature_c_radius(&mut self, radius: u16) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:89:5
#    |
# 89 |     pub fn get_parameters(&self) -> &CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:93:5
#    |
# 93 |     pub fn get_parameters_mut(&mut self) -> &mut CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:97:5
#    |
# 97 |     pub fn get_quality(&self) -> Option<u8> {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: `adder-codec-core` (lib) generated 38 warnings (run `cargo fix --lib -p adder-codec-core` to apply 3 suggestions)
# warning: unused import: `DateTime`
#  --> adder-to-dvs/src/main.rs:3:14
#   |
# 3 | use chrono::{DateTime, Local};
#   |              ^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `std::time::Instant`
#   --> adder-to-dvs/src/main.rs:14:5
#    |
# 14 | use std::time::Instant;
#    |     ^^^^^^^^^^^^^^^^^^
#
# warning: unused variable: `frame_idx`
#    --> adder-to-dvs/src/main.rs:290:29
#     |
# 290 | ...                   let frame_idx = ((old_t + 1) / frame_length) as u...
#     |                           ^^^^^^^^^ help: if this is intentional, prefix it with an underscore: `_frame_idx`
#     |
#     = note: `#[warn(unused_variables)]` on by default
#
# warning: function `set_instant_dvs_pixel` is never used
#    --> adder-to-dvs/src/main.rs:389:4
#     |
# 389 | fn set_instant_dvs_pixel(
#     |    ^^^^^^^^^^^^^^^^^^^^^
#     |
#     = note: `#[warn(dead_code)]` on by default
#
# warning: `adder-to-dvs` (bin "adder-to-dvs") generated 4 warnings (run `cargo fix --bin "adder-to-dvs"` to apply 3 suggestions)
#     Finished release [optimized] target(s) in 0.09s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/adder-to-dvs --input '/media/andrew/One Touch/HMNET_ADDER_data/gen1/17-04-21_06-54-28_1891500000_1951500000_td.adder' --output-events '/media/andrew/One Touch/HMNET_ADDER_data/gen1_dat/17-04-21_06-54-28_1891500000_1951500000_td.dat'`
# [adder-to-dvs/src/main.rs:96] args.clone() = MyArgs {
#     input: "/media/andrew/One Touch/HMNET_ADDER_data/gen1/17-04-21_06-54-28_1891500000_1951500000_td.adder",
#     output_events: "/media/andrew/One Touch/HMNET_ADDER_data/gen1_dat/17-04-21_06-54-28_1891500000_1951500000_td.dat",
#     output_mode: Binary,
#     output_video: "",
#     fps: 100.0,
#     buffer_secs: 10.0,
#     theta: 0.01,
#     show_display: false,
#     playback_slowdown: 1.0,
#     reorder: false,
# }
# Transcoding ADΔER to DVS...0%Decompressed Adu in 622920986 ns
# Transcoding ADΔER to DVS...1%Decompressed Adu in 225525882 ns
# Transcoding ADΔER to DVS...2%Decompressed Adu in 145551118 ns
# Transcoding ADΔER to DVS...3%Decompressed Adu in 616692412 ns
# Transcoding ADΔER to DVS...6%Decompressed Adu in 249014569 ns
# Transcoding ADΔER to DVS...7%Decompressed Adu in 133391215 ns
# Transcoding ADΔER to DVS...8%Decompressed Adu in 382733987 ns
# Transcoding ADΔER to DVS...9%Decompressed Adu in 289569961 ns
# Transcoding ADΔER to DVS...11%Decompressed Adu in 332169794 ns
# Transcoding ADΔER to DVS...12%Decompressed Adu in 1018592743 ns
# Transcoding ADΔER to DVS...17%Decompressed Adu in 468606710 ns
# Transcoding ADΔER to DVS...19%Decompressed Adu in 370812246 ns
# Transcoding ADΔER to DVS...21%Decompressed Adu in 1100505986 ns
# Transcoding ADΔER to DVS...26%Decompressed Adu in 387470824 ns
# Transcoding ADΔER to DVS...28%Decompressed Adu in 337778161 ns
# Transcoding ADΔER to DVS...29%Decompressed Adu in 417194546 ns
# Transcoding ADΔER to DVS...31%Decompressed Adu in 626391032 ns
# Transcoding ADΔER to DVS...34%Decompressed Adu in 542565851 ns
# Transcoding ADΔER to DVS...37%Decompressed Adu in 1497765830 ns
# Transcoding ADΔER to DVS...44%Decompressed Adu in 1339146291 ns
# Transcoding ADΔER to DVS...50%Decompressed Adu in 731460419 ns
# Transcoding ADΔER to DVS...53%Decompressed Adu in 537676980 ns
# Transcoding ADΔER to DVS...56%Decompressed Adu in 1151945358 ns
# Transcoding ADΔER to DVS...61%Decompressed Adu in 451683912 ns
# Transcoding ADΔER to DVS...63%Decompressed Adu in 652633862 ns
# Transcoding ADΔER to DVS...66%Decompressed Adu in 963679241 ns
# Transcoding ADΔER to DVS...71%Decompressed Adu in 487159385 ns
# Transcoding ADΔER to DVS...73%Decompressed Adu in 411100603 ns
# Transcoding ADΔER to DVS...75%Decompressed Adu in 1088664062 ns
# Transcoding ADΔER to DVS...80%Decompressed Adu in 524661202 ns
# Transcoding ADΔER to DVS...82%Decompressed Adu in 538918212 ns
# ...
#   --> adder-codec-core/src/codec/rate_controller.rs:24:1
#    |
# 24 | pub struct Crf {
#    | ^^^^^^^^^^^^^^
#
# warning: missing documentation for a struct
#   --> adder-codec-core/src/codec/rate_controller.rs:38:1
#    |
# 38 | pub struct CrfParameters {
#    | ^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for an associated function
#   --> adder-codec-core/src/codec/rate_controller.rs:54:5
#    |
# 54 |     pub fn new(crf: Option<u8>, plane: PlaneSize) -> Self {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:69:5
#    |
# 69 |     pub fn override_c_thresh_baseline(&mut self, baseline: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:74:5
#    |
# 74 |     pub fn override_c_thresh_max(&mut self, max: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:79:5
#    |
# 79 |     pub fn override_c_increase_velocity(&mut self, velocity: u8) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:84:5
#    |
# 84 |     pub fn override_feature_c_radius(&mut self, radius: u16) {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:89:5
#    |
# 89 |     pub fn get_parameters(&self) -> &CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:93:5
#    |
# 93 |     pub fn get_parameters_mut(&mut self) -> &mut CrfParameters {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: missing documentation for a method
#   --> adder-codec-core/src/codec/rate_controller.rs:97:5
#    |
# 97 |     pub fn get_quality(&self) -> Option<u8> {
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: `adder-codec-core` (lib) generated 38 warnings (run `cargo fix --lib -p adder-codec-core` to apply 3 suggestions)
# warning: unused import: `DateTime`
#  --> adder-to-dvs/src/main.rs:3:14
#   |
# 3 | use chrono::{DateTime, Local};
#   |              ^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `std::time::Instant`
#   --> adder-to-dvs/src/main.rs:14:5
#    |
# 14 | use std::time::Instant;
#    |     ^^^^^^^^^^^^^^^^^^
#
# warning: unused variable: `frame_idx`
#    --> adder-to-dvs/src/main.rs:290:29
#     |
# 290 | ...                   let frame_idx = ((old_t + 1) / frame_length) as u...
#     |                           ^^^^^^^^^ help: if this is intentional, prefix it with an underscore: `_frame_idx`
#     |
#     = note: `#[warn(unused_variables)]` on by default
#
# warning: function `set_instant_dvs_pixel` is never used
#    --> adder-to-dvs/src/main.rs:389:4
#     |
# 389 | fn set_instant_dvs_pixel(
#     |    ^^^^^^^^^^^^^^^^^^^^^
#     |
#     = note: `#[warn(dead_code)]` on by default
#
# warning: `adder-to-dvs` (bin "adder-to-dvs") generated 4 warnings (run `cargo fix --bin "adder-to-dvs"` to apply 3 suggestions)
#     Finished release [optimized] target(s) in 0.09s
#      Running `/home/andrew/Code/adder-codec-rs/target/release/adder-to-dvs --input '/media/andrew/One Touch/HMNET_ADDER_data/gen2/17-04-21_06-54-28_1647500000_1707500000_td.adder' --output-events '/media/andrew/One Touch/HMNET_ADDER_data/gen2_dat/17-04-21_06-54-28_1647500000_1707500000_td.dat'`
# [adder-to-dvs/src/main.rs:96] args.clone() = MyArgs {
#     input: "/media/andrew/One Touch/HMNET_ADDER_data/gen2/17-04-21_06-54-28_1647500000_1707500000_td.adder",
#     output_events: "/media/andrew/One Touch/HMNET_ADDER_data/gen2_dat/17-04-21_06-54-28_1647500000_1707500000_td.dat",
#     output_mode: Binary,
#     output_video: "",
#     fps: 100.0,
#     buffer_secs: 10.0,
#     theta: 0.01,
#     show_display: false,
#     playback_slowdown: 1.0,
#     reorder: false,
# }
# Transcoding ADΔER to DVS...0%Decompressed Adu in 142578535 ns
# Transcoding ADΔER to DVS...1%Decompressed Adu in 125024868 ns
# Transcoding ADΔER to DVS...2%Decompressed Adu in 103868027 ns
# Transcoding ADΔER to DVS...3%Decompressed Adu in 150366939 ns
# Transcoding ADΔER to DVS...4%Decompressed Adu in 157503467 ns
# Transcoding ADΔER to DVS...6%Decompressed Adu in 142745656 ns
# Transcoding ADΔER to DVS...8%Decompressed Adu in 106609352 ns
# Transcoding ADΔER to DVS...9%Decompressed Adu in 113965633 ns
# Transcoding ADΔER to DVS...10%Decompressed Adu in 229734394 ns
# Transcoding ADΔER to DVS...12%Decompressed Adu in 293853171 ns
# Transcoding ADΔER to DVS...16%Decompressed Adu in 327172329 ns
# Transcoding ADΔER to DVS...19%Decompressed Adu in 228161568 ns
# Transcoding ADΔER to DVS...22%Decompressed Adu in 268476602 ns
# Transcoding ADΔER to DVS...25%Decompressed Adu in 299622857 ns
# Transcoding ADΔER to DVS...28%Decompressed Adu in 386798644 ns
# Transcoding ADΔER to DVS...33%Decompressed Adu in 395681029 ns
# Transcoding ADΔER to DVS...37%Decompressed Adu in 271796731 ns
# Transcoding ADΔER to DVS...40%Decompressed Adu in 492706301 ns
# Transcoding ADΔER to DVS...46%Decompressed Adu in 222043600 ns
# Transcoding ADΔER to DVS...48%Decompressed Adu in 216082144 ns
# Transcoding ADΔER to DVS...51%Decompressed Adu in 285224799 ns
# Transcoding ADΔER to DVS...54%Decompressed Adu in 465792846 ns
# Transcoding ADΔER to DVS...59%Decompressed Adu in 299947791 ns
# Transcoding ADΔER to DVS...63%Decompressed Adu in 507327890 ns
# Transcoding ADΔER to DVS...68%Decompressed Adu in 302459994 ns
# Transcoding ADΔER to DVS...72%Decompressed Adu in 304118610 ns
# Transcoding ADΔER to DVS...75%Decompressed Adu in 289007226 ns
# Transcoding ADΔER to DVS...79%Decompressed Adu in 389423109 ns
# Transcoding ADΔER to DVS...83%Decompressed Adu in 477831570 ns
# Transcoding ADΔER to DVS...89%Decompressed Adu in 326044509 ns
# Transcoding ADΔER to DVS...92%Decompressed Adu in 340985549 ns
# Transcoding ADΔER to DVS...96%Decompressed Adu in 632132046 ns
# Transcoding ADΔER to DVS...104%Decompressed Adu in 269898463 ns
# Transcoding ADΔER to DVS...107%Decompressed Adu in 307899796 ns
# Transcoding ADΔER to DVS...111%Decompressed Adu in 416827860 ns
# Transcoding ADΔER to DVS...115%Decompressed Adu in 249569271 ns
# Transcoding ADΔER to DVS...118%Decompressed Adu in 414215876 ns
# Transcoding ADΔER to DVS...123%Decompressed Adu in 329437979 ns
# Transcoding ADΔER to DVS...127%Decompressed Adu in 313930614 ns
# Transcoding ADΔER to DVS...130%Decompressed Adu in 433553990 ns
# Transcoding ADΔER to DVS...135%Decompressed Adu in 347878367 ns
# Transcoding ADΔER to DVS...139%Decompressed Adu in 380712406 ns
# Transcoding ADΔER to DVS...143%Decompressed Adu in 539153683 ns
# Transcoding ADΔER to DVS...149%Decompressed Adu in 778689818 ns
# Transcoding ADΔER to DVS...158%Decompressed Adu in 490299900 ns
# Transcoding ADΔER to DVS...164%Decompressed Adu in 423615495 ns
# Transcoding ADΔER to DVS...169%Decompressed Adu in 531128916 ns
# Transcoding ADΔER to DVS...175%Decompressed Adu in 568513042 ns
# Transcoding ADΔER to DVS...181%Decompressed Adu in 565897517 ns
# Transcoding ADΔER to DVS...188%Decompressed Adu in 253617259 ns
# Transcoding ADΔER to DVS...191%Decompressed Adu in 487452222 ns
# Transcoding ADΔER to DVS...196%Decompressed Adu in 547322221 ns
# Transcoding ADΔER to DVS...202%Decompressed Adu in 364215890 ns
# Transcoding ADΔER to DVS...206%Decompressed Adu in 329847103 ns
# Transcoding ADΔER to DVS...210%Decompressed Adu in 262955348 ns
# Transcoding ADΔER to DVS...213%Decompressed Adu in 210105756 ns
# Transcoding ADΔER to DVS...215%Decompressed Adu in 228324639 ns
# Transcoding ADΔER to DVS...217%Decompressed Adu in 151182477 ns
# Transcoding ADΔER to DVS...219%Decompressed Adu in 296081263 ns
# Transcoding ADΔER to DVS...222%
#
# Finished!
# Finished processing /media/andrew/One Touch/HMNET_ADDER_data/gen2/17-04-21_06-54-28_1647500000_1707500000_td.adder
# CRF 2 done
# ['17-04-13_15-05-43_1403500000_1463500000_td.dat', '17-04-14_14-59-17_122500000_182500000_td.dat', '17-04-21_06-54-28_1891500000_1951500000_td.dat', '17-04-13_15-05-43_427500000_487500000_td.dat', '17-10-12_16-51-41_732500000_792500000_td.dat', '17-04-14_14-59-17_427500000_487500000_td.dat', '17-04-13_15-05-43_1830500000_1890500000_td.dat', '17-10-18_15-47-17_1464500000_1524500000_td.dat', '17-04-14_14-59-17_500000_60500000_td.dat', '17-04-13_15-05-43_549500000_609500000_td.dat', '17-04-21_06-54-28_2623500000_2683500000_td.dat', '17-04-13_15-05-43_1525500000_1585500000_td.dat', '17-10-18_17-12-44_854500000_914500000_td.dat', '17-10-12_16-51-41_2562500000_2622500000_td.dat', '17-04-21_09-48-10_1220500000_1280500000_td.dat', '17-04-12_19-21-02_427500000_487500000_td.dat', '17-08-24_15-42-17_610500000_670500000_td.dat', '17-08-23_17-50-46_488500000_548500000_td.dat', '17-08-24_15-42-17_244500000_304500000_td.dat', '17-04-13_15-05-43_4941500000_5001500000_td.dat', '17-08-23_17-50-46_427500000_487500000_td.dat', '17-04-13_15-05-43_5063500000_5123500000_td.dat', '17-10-12_16-51-41_2196500000_2256500000_td.dat', '17-04-21_09-48-10_3355500000_3415500000_td.dat', '17-04-21_06-54-28_1647500000_1707500000_td.dat']
# Skipping 17-04-13_15-05-43_1403500000_1463500000_td.adder
# Skipping 17-04-14_14-59-17_122500000_182500000_td.adder
# Skipping 17-04-21_06-54-28_1891500000_1951500000_td.adder
# Skipping 17-04-13_15-05-43_427500000_487500000_td.adder
# Skipping 17-10-12_16-51-41_732500000_792500000_td.adder
# Skipping 17-04-14_14-59-17_427500000_487500000_td.adder
# Skipping 17-04-13_15-05-43_1830500000_1890500000_td.adder
# Skipping 17-10-18_15-47-17_1464500000_1524500000_td.adder
# Skipping 17-04-14_14-59-17_500000_60500000_td.adder
# Skipping 17-04-13_15-05-43_549500000_609500000_td.adder
# Skipping 17-04-21_06-54-28_2623500000_2683500000_td.adder
# Skipping 17-04-13_15-05-43_1525500000_1585500000_td.adder
# Skipping 17-10-18_17-12-44_854500000_914500000_td.adder
# Skipping 17-10-12_16-51-41_2562500000_2622500000_td.adder
# Skipping 17-04-21_09-48-10_1220500000_1280500000_td.adder
# Skipping 17-04-12_19-21-02_427500000_487500000_td.adder
# Skipping 17-08-24_15-42-17_610500000_670500000_td.adder
# Skipping 17-08-23_17-50-46_488500000_548500000_td.adder
# Skipping 17-08-24_15-42-17_244500000_304500000_td.adder
# Skipping 17-04-13_15-05-43_4941500000_5001500000_td.adder
# Skipping 17-08-23_17-50-46_427500000_487500000_td.adder
# Skipping 17-04-13_15-05-43_5063500000_5123500000_td.adder
# Skipping 17-10-12_16-51-41_2196500000_2256500000_td.adder
# Skipping 17-04-21_09-48-10_3355500000_3415500000_td.adder
# Skipping 17-04-21_06-54-28_1647500000_1707500000_td.adder
# CRF 3 done
# ['17-04-13_15-05-43_1403500000_1463500000_td.dat', '17-04-14_14-59-17_122500000_182500000_td.dat', '17-04-21_06-54-28_1891500000_1951500000_td.dat', '17-04-13_15-05-43_427500000_487500000_td.dat', '17-10-12_16-51-41_732500000_792500000_td.dat', '17-04-14_14-59-17_427500000_487500000_td.dat', '17-04-13_15-05-43_1830500000_1890500000_td.dat', '17-10-18_15-47-17_1464500000_1524500000_td.dat', '17-04-14_14-59-17_500000_60500000_td.dat', '17-04-13_15-05-43_549500000_609500000_td.dat', '17-04-21_06-54-28_2623500000_2683500000_td.dat', '17-04-13_15-05-43_1525500000_1585500000_td.dat', '17-10-18_17-12-44_854500000_914500000_td.dat', '17-10-12_16-51-41_2562500000_2622500000_td.dat', '17-04-21_09-48-10_1220500000_1280500000_td.dat', '17-04-12_19-21-02_427500000_487500000_td.dat', '17-08-24_15-42-17_610500000_670500000_td.dat', '17-08-23_17-50-46_488500000_548500000_td.dat', '17-08-24_15-42-17_244500000_304500000_td.dat', '17-04-13_15-05-43_4941500000_5001500000_td.dat', '17-08-23_17-50-46_427500000_487500000_td.dat', '17-04-13_15-05-43_5063500000_5123500000_td.dat', '17-10-12_16-51-41_2196500000_2256500000_td.dat', '17-04-21_09-48-10_3355500000_3415500000_td.dat', '17-04-21_06-54-28_1647500000_1707500000_td.dat']
# Skipping 17-04-13_15-05-43_1403500000_1463500000_td.adder
# Skipping 17-04-14_14-59-17_122500000_182500000_td.adder
# Skipping 17-04-21_06-54-28_1891500000_1951500000_td.adder
# Skipping 17-04-13_15-05-43_427500000_487500000_td.adder
# Skipping 17-10-12_16-51-41_732500000_792500000_td.adder
# Skipping 17-04-14_14-59-17_427500000_487500000_td.adder
# Skipping 17-04-13_15-05-43_1830500000_1890500000_td.adder
# Skipping 17-10-18_15-47-17_1464500000_1524500000_td.adder
# Skipping 17-04-14_14-59-17_500000_60500000_td.adder
# Skipping 17-04-13_15-05-43_549500000_609500000_td.adder
# Skipping 17-04-21_06-54-28_2623500000_2683500000_td.adder
# Skipping 17-04-13_15-05-43_1525500000_1585500000_td.adder
# Skipping 17-10-18_17-12-44_854500000_914500000_td.adder
# Skipping 17-10-12_16-51-41_2562500000_2622500000_td.adder
# Skipping 17-04-21_09-48-10_1220500000_1280500000_td.adder
# Skipping 17-04-12_19-21-02_427500000_487500000_td.adder
# Skipping 17-08-24_15-42-17_610500000_670500000_td.adder
# Skipping 17-08-23_17-50-46_488500000_548500000_td.adder
# Skipping 17-08-24_15-42-17_244500000_304500000_td.adder
# Skipping 17-04-13_15-05-43_4941500000_5001500000_td.adder
# Skipping 17-08-23_17-50-46_427500000_487500000_td.adder
# Skipping 17-04-13_15-05-43_5063500000_5123500000_td.adder
# Skipping 17-10-12_16-51-41_2196500000_2256500000_td.adder
# Skipping 17-04-21_09-48-10_3355500000_3415500000_td.adder
# Skipping 17-04-21_06-54-28_1647500000_1707500000_td.adder
# CRF 6 done
# ['17-04-13_15-05-43_1403500000_1463500000_td.dat', '17-04-14_14-59-17_122500000_182500000_td.dat', '17-04-21_06-54-28_1891500000_1951500000_td.dat', '17-04-13_15-05-43_427500000_487500000_td.dat', '17-10-12_16-51-41_732500000_792500000_td.dat', '17-04-14_14-59-17_427500000_487500000_td.dat', '17-04-13_15-05-43_1830500000_1890500000_td.dat', '17-10-18_15-47-17_1464500000_1524500000_td.dat', '17-04-14_14-59-17_500000_60500000_td.dat', '17-04-13_15-05-43_549500000_609500000_td.dat', '17-04-21_06-54-28_2623500000_2683500000_td.dat', '17-04-13_15-05-43_1525500000_1585500000_td.dat', '17-10-18_17-12-44_854500000_914500000_td.dat', '17-10-12_16-51-41_2562500000_2622500000_td.dat', '17-04-21_09-48-10_1220500000_1280500000_td.dat', '17-04-12_19-21-02_427500000_487500000_td.dat', '17-08-24_15-42-17_610500000_670500000_td.dat', '17-08-23_17-50-46_488500000_548500000_td.dat', '17-08-24_15-42-17_244500000_304500000_td.dat', '17-04-13_15-05-43_4941500000_5001500000_td.dat', '17-08-23_17-50-46_427500000_487500000_td.dat', '17-04-13_15-05-43_5063500000_5123500000_td.dat', '17-10-12_16-51-41_2196500000_2256500000_td.dat', '17-04-21_09-48-10_3355500000_3415500000_td.dat', '17-04-21_06-54-28_1647500000_1707500000_td.dat']
# Skipping 17-04-13_15-05-43_1403500000_1463500000_td.adder
# Skipping 17-04-14_14-59-17_122500000_182500000_td.adder
# Skipping 17-04-21_06-54-28_1891500000_1951500000_td.adder
# Skipping 17-04-13_15-05-43_427500000_487500000_td.adder
# Skipping 17-10-12_16-51-41_732500000_792500000_td.adder
# Skipping 17-04-14_14-59-17_427500000_487500000_td.adder
# Skipping 17-04-13_15-05-43_1830500000_1890500000_td.adder
# Skipping 17-10-18_15-47-17_1464500000_1524500000_td.adder
# Skipping 17-04-14_14-59-17_500000_60500000_td.adder
# Skipping 17-04-13_15-05-43_549500000_609500000_td.adder
# Skipping 17-04-21_06-54-28_2623500000_2683500000_td.adder
# Skipping 17-04-13_15-05-43_1525500000_1585500000_td.adder
# Skipping 17-10-18_17-12-44_854500000_914500000_td.adder
# Skipping 17-10-12_16-51-41_2562500000_2622500000_td.adder
# Skipping 17-04-21_09-48-10_1220500000_1280500000_td.adder
# Skipping 17-04-12_19-21-02_427500000_487500000_td.adder
# Skipping 17-08-24_15-42-17_610500000_670500000_td.adder
# Skipping 17-08-23_17-50-46_488500000_548500000_td.adder
# Skipping 17-08-24_15-42-17_244500000_304500000_td.adder
# Skipping 17-04-13_15-05-43_4941500000_5001500000_td.adder
# Skipping 17-08-23_17-50-46_427500000_487500000_td.adder
# Skipping 17-04-13_15-05-43_5063500000_5123500000_td.adder
# Skipping 17-10-12_16-51-41_2196500000_2256500000_td.adder
# Skipping 17-04-21_09-48-10_3355500000_3415500000_td.adder
# Skipping 17-04-21_06-54-28_1647500000_1707500000_td.adder
# CRF 9 done
